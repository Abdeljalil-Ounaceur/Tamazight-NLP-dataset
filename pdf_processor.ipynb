# %%
# Install required libraries (run this first if packages aren't installed)
# %pip install PyPDF2 tabula-py pandas openpyxl
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (3.0.1)
# Requirement already satisfied: tabula-py in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (2.10.0)
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (2.3.1)
# Requirement already satisfied: openpyxl in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>1.24.4 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from tabula-py) (2.2.1)
# Requirement already satisfied: distro in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from tabula-py) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import PyPDF2
import pandas as pd
import tabula
import os
from pathlib import Path

# Set the PDF file path
pdf_path = "Tamazight-English-Dictionary-2007.pdf"
print(f"Working with PDF: {pdf_path}")
print(f"File exists: {os.path.exists(pdf_path)}")
# Out:
# Working with PDF: Tamazight-English-Dictionary-2007.pdf
# File exists: True

# %%
# Get basic PDF information without reading all content
def preview_pdf_info(pdf_path):
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        num_pages = len(pdf_reader.pages)
        
        print(f"PDF Information:")
        print(f"- Total pages: {num_pages}")
        print(f"- File size: {os.path.getsize(pdf_path) / (1024*1024):.2f} MB")
        
        # Read first page sample
        print(f"\n--- Sample from first page ---")
        first_page = pdf_reader.pages[0]
        sample_text = first_page.extract_text()[:500]
        print(sample_text)
        
        return num_pages

num_pages = preview_pdf_info(pdf_path)
# Out:
# PDF Information:
# - Total pages: 153
# - File size: 3.67 MB
#
# --- Sample from first page ---
#
#
# Acknowledgement
#
#
# This monolingual Tamazight Dictionary is the product of several months of serious work, dedication and determination of PCV/ Morocco Stacy Alboher (2005- 2007).
#  Many thanks go to all those who have contributed to the collection of words contained in this dictionary or helped verify the diverse meanings of these words.   While Stacy stated that this work is by no means exhaustive, I strongly believe that it has great utility in helping PCVs / PCTs with their Tamazig

# %%
# %pip install jpype1

# Extract all tables from the PDF
print("Extracting tables from PDF...")
try:
    # Extract tables from all pages (this might take a moment)
    all_tables = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)
    print(f"Successfully extracted {len(all_tables)} tables from the PDF")
except Exception as e:
    print(f"Error extracting tables: {e}")
    # Fallback: try first 10 pages
    all_tables = tabula.read_pdf(pdf_path, pages='1-10', multiple_tables=True)
    print(f"Extracted {len(all_tables)} tables from first 10 pages")
# Out:
# Extracting tables from PDF...
# Successfully extracted 238 tables from the PDF

# %%
# Display information about each table and show samples
for i, table in enumerate(all_tables):  # Show first 5 tables
    print(f"\n{'='*60}")
    print(f"TABLE {i+1}")
    print(f"{'='*60}")
    print(f"Shape: {table.shape} (rows x columns)")
    print(f"Columns: {list(table.columns)}")
    
    # Clean the table (remove empty rows/columns)
    all_tables[i] = table.dropna(how='all').dropna(axis=1, how='all')
    print(f"Shape after cleaning: {all_tables[i].shape}")
    
    print(f"\nFirst 5 rows:")
    print(all_tables[i].head())
    
    if len(all_tables) > 5 and i == 4:
        print(f"\n... and {len(all_tables) - 5} more tables")
# Out:
# ============================================================
# TABLE 1
# ============================================================
# Shape: (57, 3) (rows x columns)
# Columns: ['1', 'yan; yiwn/yat, yiwt', 'Unnamed: 0']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#    1 yan; yiwn/yat, yiwt
# 0  2            sin/snat
# 1  3          krad/kradt
# 2  4                rbعa
# 3  5                xmsa
# 4  6                 sţa
#
# ============================================================
# TABLE 2
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['a person or place\r(indicates movement)', 'Zars']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#   a person or place\r(indicates movement)       Zars
# 0                             a while ago   šHal aya
# 1                       abnormal (person)       nHya
# 2                                abortion    l-ijhaď
# 3                                   about    ġif; xf
# 4                                   above  afla; nig
#
# ============================================================
# TABLE 3
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['Allah (figurative\rspeech)', 'bu itran']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#   Allah (figurative\rspeech)                bu itran
# 0                  alligator                 ttimsaH
# 1                     almond                    lluz
# 2                     almost  .عlaHal; .عlaiyn; druġ
# 3                      alone          i iġf^; i ixf^
# 4                   alphabet          lhja; lHuruf**
#
# ============================================================
# TABLE 4
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['artist', 'Lfnnan']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#                  artist                     Lfnnan
# 0                   ash                  iġd; iġid
# 1                 ashes                       Irġd
# 2               ashtray                     Tffaya
# 3                  Asia                       Asya
# 4  asleep, part of body  tumzi tušnt g +body\rpart
#
# ============================================================
# TABLE 5
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['bangs (hair)', 'tawnza']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#       bangs (hair)          tawnza
# 0             bank          lbanka
# 1     banyo, metal           ššfna
# 2  barbary macaque           zعtut
# 3           barber  ahjjam; ahssan
# 4          barbers         ihadjmn
#
# ... and 233 more tables
#
# ============================================================
# TABLE 6
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['beets', 'Lbarba']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#            beets                           Lbarba
# 0         before                         dat; qbl
# 1  before (time)                               Ql
# 2         beggar  ddriwš; inmmtri;\rlmskin; mskin
# 3        begging                            Tutra
# 4      beginning                  tizwuri; tzwari
#
# ============================================================
# TABLE 7
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['blond', 'ašhabun; azrwal']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#            blond  ašhabun; azrwal
# 0          blood            idamn
# 1   blood vessel            azġur
# 2  blood vessels          izġuran
# 3     blue (adj)  ajnjari; azarqi
# 4       blue sky           asmawi
#
# ============================================================
# TABLE 8
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['Unnamed: 0', 'dblij**']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#            Unnamed: 0                  dblij**
# 0           bracelets                   Izbyan
# 1            brag (n)                     sHam
# 2               braid                   Aqaroi
# 3               brain  allġf; dmaġ; lعql; anli
# 4  bran (for animals)                    Ilamn
#
# ============================================================
# TABLE 9
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['bubbles', 'tibiwlin']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#                       bubbles                        tibiwlin
# 0                      bucket  ataš; aţaz; attas; lkob;\rsstl
# 1  bucket, measuring\r(metal)                           lعbrt
# 2                bucket, well                             aga
# 3                     buckets                          attasn
# 4                        bugs                          ibxušn
#
# ============================================================
# TABLE 10
# ============================================================
# Shape: (36, 2) (rows x columns)
# Columns: ['calf (female)', 'Tigizt']
# Shape after cleaning: (36, 2)
#
# First 5 rows:
#                       calf (female)              Tigizt
# 0                    call to prayer              l'adan
# 1    call to prayer, 1st\r(sunrise)               l-fjr
# 2       call to prayer, 2nd\r(noon)  tizwarnin; dduhr**
# 3  call to prayer, 3rd\r(afternoon)               Lعaşr
# 4     call to prayer, 4th\r(sunset)   lmuġrb; tin wutši
#
# ============================================================
# TABLE 11
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['ceiling*', 'sqf']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#                  ceiling*             sqf
# 0                  cement            sima
# 1                cemetary  lqbur; tamdint
# 2                  census           liHşa
# 3               centipede      dad nuašal
# 4  ceremony, baby\rnaming            sibع
#
# ============================================================
# TABLE 12
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['churn, made from\ranimal skin(n)', 'tijwit']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#   churn, made from\ranimal skin(n)     tijwit
# 0                       cigarettes     lgarru
# 1                         cilantro     lqzbur
# 2                     cinder block      lbrik
# 3                         cinnamon      lqrfa
# 4                           circle  tabrrrayt
#
# ============================================================
# TABLE 13
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['comedian', 'baqšiš']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#           comedian     baqšiš
# 0      common hare    tawtult
# 1          Commune    ljamaعa
# 2  community group    taqbilt
# 3          company     šarika
# 4      competition  lmunafasa
#
# ============================================================
# TABLE 14
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['counter', 'lkuntwar']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#       counter           lkuntwar
# 0     country  tamazirt; ddula**
# 1       court            lmHkama
# 2  courthouse            lmHkama
# 3   courtyard             arHabi
# 4    couscous        sksu; ţţعam
#
# ============================================================
# TABLE 15
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['curse, magical', 'taymust']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#         curse, magical         taymust
# 0             curtains   lxamya; rridu
# 1                curve         lvirage
# 2               curves        lvirajat
# 3              cut (n)            ubui
# 4  dance (traditional)  aHaydus; aHwaš
#
# ============================================================
# TABLE 16
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['dirt (on ground)', 'akal; ašal']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#    dirt (on ground)      akal; ašal
# 0  dirt (on person)     iršan; lusx
# 1       dirty (adj)     iwssx; ijlx
# 2       dirty water           iršan
# 3    disabled (adj)  akušam; lmuعaq
# 4            dishes         irukutn
#
# ============================================================
# TABLE 17
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['dream (n)', 'tawargit']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#       dream (n)                    tawargit
# 0     dress (n)  lqsua; aqaydur;\rtawjdanit
# 1   dress shirt                     lqamija
# 2       dresser                      lmaryu
# 3     drink (n)                      tmswit
# 4  drinking (n)                       tissi
#
# ============================================================
# TABLE 18
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['either', 'ima']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#             either              ima
# 0            elbow  tiġmrin; tiġmrt
# 1        election*         lintixab
# 2    electric cord      lxiţ n usid
# 3  electric outlet            lpriz
# 4      electricity             asid
#
# ============================================================
# TABLE 19
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['eye', 'ţiţ']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#              eye                              ţiţ
# 0  eye, white of                      timli n ţiţ
# 1       eyebrows                   timiwa; timuwa
# 2     eyeglasses            lmdadr; lmdrat; nďaďr
# 3      eyelashes  argaln; arjaln; aryaln;\rašbabn
# 4           eyes                              aln
#
# ============================================================
# TABLE 20
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['fever', 'tamġart; tawla; sxana']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#        fever tamġart; tawla; sxana
# 0  few (adj)                 idrus
# 1    few (n)                  imik
# 2     fiance                tislit
# 3    fiancee               lxatiba
# 4     fibula               tisruns
#
# ============================================================
# TABLE 21
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['flatterer', 'asHHar']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#     flatterer            asHHar
# 0  flatterers           isHHarn
# 1        flea    agurdu; awurdu
# 2       fleas  igurdan; iwurdan
# 3       flesh            tifiyi
# 4       flies              izan
#
# ============================================================
# TABLE 22
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['form (paper)', 'tawirqt']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#    form (paper)                             tawirqt
# 0           fox  aعlbun; baġu; baġuġ;\rbarġn; išعab
# 1         foxes                              iعlban
# 2      free (n)                               fabur
# 3       freedom                   lHurriya*; tilili
# 4  french fries                               lfrit
#
# ============================================================
# TABLE 23
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['girls', 'talqumin; tirbatin;\rtiširatin']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#               girls talqumin; tirbatin;\rtiširatin
# 0           glacoma                   amalu n waln
# 1             glass                           jjaj
# 2  glass (drinking)                          lkass
# 3      glasses, eye                 nďaďar; nţaţar
# 4             glove                  tqašr n wafus
#
# ============================================================
# TABLE 24
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['gravestone', 'tanmnirt']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#     gravestone    tanmnirt
# 0  gravestones     tmnirin
# 1    graveyard     tamdint
# 2        gray*      armadi
# 3    graze (n)      tayssa
# 4        greed  jju;ع ţţmع
#
# ============================================================
# TABLE 25
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['hands', 'ifasn']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#             hands    ifasn
# 0        handspan  tardast
# 1     harassment*    nggan
# 2        hardship   tamara
# 3  hardware store  ddrugri
# 4         harelip   afriat
#
# ============================================================
# TABLE 26
# ============================================================
# Shape: (36, 2) (rows x columns)
# Columns: ['heroin', 'ihirwin']
# Shape after cleaning: (36, 2)
#
# First 5 rows:
#                        heroin        ihirwin
# 0                        hers  win-ns/tin-ns
# 1                      hiccup         tiqqst
# 2                        hill        tawrirt
# 3                         him           ntta
# 4  him (direct obj.\rpronoun)             -t
#
# ============================================================
# TABLE 27
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['houses', 'tadarwin; tidartwin']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#                 houses tadarwin; tidartwin
# 0  how (interrogative)  manimš; manimšidda
# 1             how much        mšta; sHal**
# 2          human being               bnadm
# 3        human rights*        Huquq linsan
# 4          hummingbird              Hyayyu
#
# ============================================================
# TABLE 28
# ============================================================
# Shape: (36, 2) (rows x columns)
# Columns: ['instructions*', 'ttعlimat']
# Shape after cleaning: (36, 2)
#
# First 5 rows:
#   instructions*   ttعlimat
# 0     insurance   rasurans
# 1   interesting      ihmma
# 2  intersection  gr ibrdan
# 3     intestine       asrm
# 4    intestines     isrman
#
# ============================================================
# TABLE 29
# ============================================================
# Shape: (46, 2) (rows x columns)
# Columns: ['job', 'lxdmt']
# Shape after cleaning: (42, 2)
#
# First 5 rows:
#                  job   lxdmt
# 0         jocularity   rršqt
# 1  joint (i.e. knee)   lmsfl
# 2               joke  nnukta
# 3              joker  baqšiš
# 4   joker (in cards)  jjokir
#
# ============================================================
# TABLE 30
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['leather', 'jjld']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#     leather    jjld
# 0  leather*   lkwir
# 1    leaves  ifrawn
# 2      left  azlmat
# 3   lentils    lعds
# 4   leprosy    lbrş
#
# ============================================================
# TABLE 31
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['locust', 'tamurġi']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#               locust tamurġi
# 0               logs   iquva
# 1          lollipops  lmşaşa
# 2         loneliness    lqnd
# 3  longing (for) (n)  taġufi
# 4               loom    asţa
#
# ============================================================
# TABLE 32
# ============================================================
# Shape: (33, 2) (rows x columns)
# Columns: ['mattress', 'lbayas; namusiya']
# Shape after cleaning: (33, 2)
#
# First 5 rows:
#         mattress lbayas; namusiya
# 0      mausoleum          agurram
# 1  mauve (color)         aHarmlal
# 2            May  mayyu; šar xmsa
# 3          maybe            .عniġ
# 4          mayor  ajrray; muqadam
#
# ============================================================
# TABLE 33
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['piece', 'Unnamed: 0']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#                           piece     Unnamed: 0
# 0  metal, flat, to put on\rroof         aqzdir
# 1               meter (in taxi)        lkuntur
# 2                          mice        iġrdayn
# 3                   microscope*        lmijhar
# 4                      military  aعskri; lعskr
#
# ============================================================
# TABLE 34
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['mortar and pestle', 'tafrdut']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#     mortar and pestle            tafrdut
# 0  mortar and pestle*             lmhraz
# 1              mosque              ljamع
# 2            mosquito              abiba
# 3               most*          l-aġlabya
# 4                moth  ibilbilu; ibrbilu
#
# ============================================================
# TABLE 35
# ============================================================
# Shape: (54, 4) (rows x columns)
# Columns: ['nature', 'ţţabiعa', 'not (for nouns or', 'urid']
# Shape after cleaning: (54, 4)
#
# First 5 rows:
#             nature     ţţabiعa not (for nouns or                      urid
# 0      naughtiness      tamssi         pronouns)                       NaN
# 1   naughty person  lm'sxut(a)      not possible  ur af (conj in past); ur
# 2           nausea    timlilay               NaN                     imkin
# 3  near (location)      tama n           not yet                      urta
# 4        necessary       labda          notebook                   lkunnaš
#
# ============================================================
# TABLE 36
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['opening in front of\rshirt (women)', 'awsi']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#   opening in front of\rshirt (women)               awsi
# 0                            opinion                ray
# 1                           opinions  id rray; larriyat
# 2                        opportunity             lfurşa
# 3                           opposite         ďď'd; lعks
# 4                        optomistic*           mutafail
#
# ============================================================
# TABLE 37
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['panties', 'lgrsun; slip']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#     panties   lgrsun; slip
# 0     pants  asrwl; ssrwal
# 1     paper        tawriqt
# 2   paprika         tHmira
# 3    parade      listiعrat
# 4  paradise           ljnt
#
# ============================================================
# TABLE 38
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['people', 'mddn']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#                  people    mddn
# 0  people (of 1 nation)     šعb
# 1    people, high birth    šrfa
# 2     people, low birth  iعamin
# 3          people, poor   drawš
# 4   peoples (of nation)  ššuعub
#
# ============================================================
# TABLE 39
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['phone number', 'nmra n tilifun']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#   phone number nmra n tilifun
# 0   photograph         tswira
# 1  photographs          tsawr
# 2     pick-axe         ašaqur
# 3       picnic         rriHla
# 4     pictures          tsawr
#
# ============================================================
# TABLE 40
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['plus (math)', 'zaid']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#   plus (math)              zaid
# 0      pocket        jjib; jjnb
# 1       poem*             ššiعr
# 2       poems          timnaţin
# 3        poet  amdiaz; ššaعir**
# 4      poison               ssm
#
# ============================================================
# TABLE 41
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['pressure', 'ďďġţ']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#                   pressure          ďďġţ
# 0          pressure cooker        lkukut
# 1             pretty (adj)          iHla
# 2                    price  atig; ttaman
# 3                priceless  ur ġurs atig
# 4  pricklies (in raw wool)        azumar
#
# ============================================================
# TABLE 42
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['quality', 'kaliti']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#             quality         kaliti
# 0           quarter     rabعa; rbع
# 1             queen       tayllidt
# 2          question  asqsa; sual**
# 3           quickly         fimrra
# 4  quill (in plant)   asnan; axlal
#
# ============================================================
# TABLE 43
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['religion', 'ddin']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#                      religion        ddin
# 0                     removal        ukus
# 1                    rent (n)  lkra; lkri
# 2                      report      rrapur
# 3  representative (in\rgov't)        nayb
# 4                    republic    jamhuria
#
# ============================================================
# TABLE 44
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['rotten (n)', 'axmmuj']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#   rotten (n)         axmmuj
# 0      round         amduwr
# 1  rug, wool  ahadun; iHnbl
# 2    running          tazla
# 3       rust    şda; taniyt
# 4       sack          lxnšt
#
# ============================================================
# TABLE 45
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['scissors', 'lmqşş; tuzlin']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#                          scissors       lmqşş; tuzlin
# 0                         scooter              lmutur
# 1                        scorpion  tiġirdmt; tiraġdmt
# 2                         scratch              axbbuš
# 3               screen (in widow)               šbbik
# 4  screen (t.v.,\rcomputer, etc.)              š-šaša
#
# ============================================================
# TABLE 46
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['sheet', 'lizar']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#          sheet          lizar
# 0  sheet metal        aqazdir
# 1        shelf            rrf
# 2      shelves  isyaln; rrfuf
# 3     shephard          amksa
# 4    shepherds        imksawn
#
# ============================================================
# TABLE 47
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['sink', 'lavabu; ššarij n irukutn']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#             sink lavabu; ššarij n irukutn
# 0        sip (n)                 tagumimt
# 1            sir                     sidi
# 2    sister (my)                     utma
# 3  sister-in-law           tamţut n igma^
# 4        sisters        istmatn; tawmatin
#
# ============================================================
# TABLE 48
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['snow', 'adfl; atfl']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#                 snow     adfl; atfl
# 0     so (therefore)           uxla
# 1  so that (purpose)           mrad
# 2               soap         şşabun
# 3             soccer  lkura; takurt
# 4               sock       tarġiwin
#
# ============================================================
# TABLE 49
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['spare (n) (i.e. tire)', 'sikur']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#   spare (n) (i.e. tire)         sikur
# 0             spark (n)          aşft
# 1                sparks       işftawn
# 2              special*          xass
# 3           spectators*  lmutafrrijin
# 4                speech          awal
#
# ============================================================
# TABLE 50
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['steel wool', 'jiks']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#                   steel wool     jiks
# 0                 stench (n)    rriHt
# 1           steps, on stairs   ddrjat
# 2                      stick  taġruyt
# 3  stick (esp. for\rbeating)  taġruyt
# 4        stick (for beating)   amعrad
#
# ============================================================
# TABLE 51
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['suede', 'ddan']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#                suede              ddan
# 0              sugar            sskkar
# 1    sugar container           tarbiعt
# 2  sugar, granulated           ssanida
# 3        suggestions           id rray
# 4           suitcase  lbaliza; lvaliza
#
# ============================================================
# TABLE 52
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['teaching (n)', 'ttعlim']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#            teaching (n)                          ttعlim
# 0                teapot                          lbrrad
# 1                 tears                         imttawn
# 2  technical assistance                 ttaعawun ttiqni
# 3                 teeth  tuġmas; tuxmas;\rtuxsin; uxsan
# 4            television                          tlfaza
#
# ============================================================
# TABLE 53
# ============================================================
# Shape: (35, 2) (rows x columns)
# Columns: ['them (M) (direct obj.\rpronoun)', '-tn']
# Shape after cleaning: (35, 2)
#
# First 5 rows:
#      them (M) (direct obj.\rpronoun)                -tn
# 0  them (M) (indirect\robj. pronoun)               -asn
# 1                    then (emphatic)               bعda
# 2                  then (sequential)               aywa
# 3                  then (sequential)               ukan
# 4                              there  din; dinaġ; yurin
#
# ============================================================
# TABLE 54
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['tibea', 'aġanim n udar']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#          tibea     aġanim n udar
# 0       ticket           tawriqt
# 1   tickle (n)  tiglgat; tiklkad
# 2        tiger            aġilas
# 3  tilling (n)             lqliv
# 4         time              lHal
#
# ============================================================
# TABLE 55
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['to applaud', 'ďhr; şffq; ut rršš; wt\rabqqa']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#               to applaud ďhr; şffq; ut rršš; wt\rabqqa
# 0           to apply for                           ttr
# 1             to approve                           qbl
# 2               to argue                            zi
# 3  to arrange a marriage                         stahl
# 4              to arrest                      amz; ţţf
#
# ============================================================
# TABLE 56
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['to be brave', '.عzzu; zعm']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#     to be brave      .عzzu; zعm
# 0  to be bright           ssidd
# 1  to be broken              rz
# 2  to be burned       ġus; kumt
# 3   to be burnt             kmď
# 4    to be busy  ur sala (conj)
#
# ============================================================
# TABLE 57
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['to be dirty', 'jlx; wssx']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#               to be dirty   jlx; wssx
# 0           to be distant   .عrq; bعd
# 1             to be dizzy  dwx; mlili
# 2             to be drunk         skr
# 3  to be dry (i.e. bread)         qar
# 4              to be easy         rxu
#
# ============================================================
# TABLE 58
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['to be immature', 'fsis; imzi* lعql']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#       to be immature fsis; imzi* lعql
# 0   to be in a hurry        Harš; zrb
# 1    to be in charge             qabl
# 2     to be in peace             hnna
# 3  to be intelligent              šwu
# 4   to be interested            ihmma
#
# ============================================================
# TABLE 59
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['to be patient', 'şbr']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#           to be patient                                   şbr
# 0     to be pleasing to                                  .عjb
# 1            to be poor  dعf; Htadja; g (conj)\rlmskin/igllin
# 2        to be possible                                    ml
# 3        to be pregnant          aru (conj in present\rtense)
# 4  to be prepared (adj)                                   wjd
#
# ============================================================
# TABLE 60
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['to be strong', 'şHu']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#             to be strong     şHu
# 0        to be surprised     rعb
# 1          to be swollen     bzi
# 2             to be tall    ġzif
# 3          to be tangled  mmarks
# 4  to be tense (muscles)    qqrş
#
# ============================================================
# TABLE 61
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['to benefit from', 'snf;ع stafd**']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#          to benefit from snf;ع stafd**
# 0              to betray           ġďr
# 1                to bite      qjj; qrš
# 2      to bite (insects)           qqs
# 3              to blame*           lum
# 4  to bleat (i.e. sheep)          sbiع
#
# ============================================================
# TABLE 62
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['to catch up to', 'ssikl']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#                     to catch up to          ssikl
# 0                         to cause          sbb'b
# 1  to cause something\rnot to work           sxsr
# 2                     to cauterize            qqd
# 3                     to celebrate  g lfrH; Htafl
# 4                        to change           bddl
#
# ============================================================
# TABLE 63
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['to cough phlegm', 'sxixi']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#            to cough phlegm        sxixi
# 0                 to count  Hasb; zmm'm
# 1                 to cover           dl
# 2  to cover (a dead\rbody)        adr i
# 3                 to covet          ţmع
# 4                 to crack          sţġ
#
# ============================================================
# TABLE 64
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['to disappear (behind\rsomething)', 'ġġli']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#   to disappear (behind\rsomething)            ġġli
# 0                      to discover              af
# 1                       to discuss            naqš
# 2                       to dislike  ur Hmil (conj)
# 3                     to dismantle            smun
# 4                      to dismount             ggz
#
# ============================================================
# TABLE 65
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['to embroider', 'nqš']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#   to embroider    nqš
# 0     to empty    xwu
# 1       to end  fukku
# 2    to endure    şbr
# 3     to enjoy   brrع
# 4   to enlarge   swsع
#
# ============================================================
# TABLE 66
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['to fear', 'ggd']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#            to fear   ggd
# 0          to feed   stš
# 1  to feed animals  .عlf
# 2          to feel  Hssa
# 3      to fence in  suty
# 4         to fight  nnaġ
#
# ============================================================
# TABLE 67
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ["to get in someone's\rway", 'tعrrď']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#        to get in someone's\rway      tعrrď
# 0                to get married  awl; tahl
# 1                    to get old       wsir
# 2                     to get on  ali s; ni
# 3  to get sick (from\rdrinking)     tušiyr
# 4                     to get up        nkr
#
# ============================================================
# TABLE 68
# ============================================================
# Shape: (53, 4) (rows x columns)
# Columns: ['to hang', 'agl', 'Unnamed: 0', 'v)']
# Shape after cleaning: (53, 4)
#
# First 5 rows:
#                to hang       agl        Unnamed: 0    v)
# 0       to hang to dry       fsr  to hurt (injure)   brš
# 1            to happen   aġ; jru           to husk   zlm
# 2  to harvest (grains)       mgr         to ignore  nxxl
# 3   to harvest (grass)       Hšš        to imagine  xayl
# 4              to hate  krh; mqt        to imitate  qlld
#
# ============================================================
# TABLE 69
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['to leave behind', 'zri']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#              to leave behind    zri
# 0                    to lend    rdl
# 1                to lengthen  sġzif
# 2                  to lessen  sdris
# 3                     to let    adj
# 4  to let go (of\rsomething)    zdu
#
# ============================================================
# TABLE 70
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['to lull (a baby)', 'srurd']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#                   to lull (a baby)       srurd
# 0                       to magnify       sxitr
# 1                      to maintain  Hafd (ġif)
# 2                          to make  skr; Hiyya
# 3                to make a mistake         xďu
# 4  to make a woman\rpregnant (man)       ssirw
#
# ============================================================
# TABLE 71
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['to make something\rhappen, by force', 'g ddrع']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#   to make something\rhappen, by force      g ddrع
# 0         to make something\rthe same      siksil
# 1                        to make stop        sbdd
# 2                         to make tea  .عmmr atay
# 3                       to make tired        swHl
# 4                  to make understood        sfhm
#
# ============================================================
# TABLE 72
# ============================================================
# Shape: (43, 2) (rows x columns)
# Columns: ['Unnamed: 0', '(reflexive)']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#     Unnamed: 0  (reflexive)
# 0      to obey          ţaع
# 1   to oblige*        bzz'z
# 2  to observe*         laHď
# 3    to occupy  .عmmr adġar
# 4     to occur          jru
#
# ============================================================
# TABLE 73
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['to pound', 'ddz']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#                 to pound       ddz
# 0                to pour  ffi; xwu
# 1            to practice       lmd
# 2              to praise       škr
# 3                to pray      zzal
# 4  to pray for something       dعu
#
# ============================================================
# TABLE 74
# ============================================================
# Shape: (42, 2) (rows x columns)
# Columns: ['to recover', 'jji']
# Shape after cleaning: (42, 2)
#
# First 5 rows:
#              to recover                    jji
# 0             to reduce                   naqs
# 1  to refuse (not want)                 ur iri
# 2           to register            zmm'm; qyyd
# 3             to regret  griz (reflexive); ndm
# 4              to relax           rtaH; swunfu
#
# ============================================================
# TABLE 75
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['to rust', 'sdda']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#       to rust  sdda
# 0     to save   Hďu
# 1      to say   ini
# 2    to scare  siwd
# 3  to scatter  zllع
# 4    to score  sjjl
#
# ============================================================
# TABLE 76
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['to sift', 'ssif']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#        to sift  ssif
# 0      to sign  snya
# 1   to silence  sfst
# 2  to simplify  suhn
# 3      to sing  ġnna
# 4      to sink   ġrq
#
# ============================================================
# TABLE 77
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['to spread', 'fsr']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#        to spread                                     fsr
# 0  to spread out                                     ġrď
# 1      to sprout                                     mġi
# 2       to squat  qqim xf tiġiġiyin; ut\r(conj) tiġuzvav
# 3     to squeeze                          .عşr; ziyr; zm
# 4       to stain                                     slġ
#
# ============================================================
# TABLE 78
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['to swallow', 'lqm; zrع']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#   to swallow        lqm; zrع
# 0   to swear            ggal
# 1   to sweat            .عrg
# 2   to sweep  frď; slH; šţţb
# 3   to swell            bziy
# 4    to swim       .عum; ššf
#
# ============================================================
# TABLE 79
# ============================================================
# Shape: (38, 2) (rows x columns)
# Columns: ['to throw out (liquid)', 'nġl']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#                      to throw out (liquid)        nġl
# 0  to throw something\rinto a hard surface        ġrf
# 1                                to tickle  g tiglgaď
# 2                                   to tie  ass; Hzzm
# 3                        to tie (i.e. cow)        krf
# 4                            to tie closed       jnnţ
#
# ============================================================
# TABLE 80
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['to use up', 'smur']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#           to use up                       smur
# 0      to vaccinate  jlb; wzi; g (conj) tissmi
# 1          to visit                          k
# 2  to visit (saint)                        zur
# 3          to vomit                 rar; shušr
# 4           to vote                       şwwt
#
# ============================================================
# TABLE 81
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['to worship', '.عbd']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#                        to worship           .عbd
# 0                        to wound            jrH
# 1                         to wrap           duar
# 2                        to write  ara; ktb; uru
# 3               to write (a note)          m'rka
# 4  to write (official\rdocuments)           zm'm
#
# ============================================================
# TABLE 82
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['trash', 'aşlaH; lkurfi; zzbl']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#                 trash aşlaH; lkurfi; zzbl
# 0           traveling               safar
# 1         travels (n)              tHawis
# 2                tray              şşinit
# 3           treasurer           amin lmal
# 4  treatment, medical              asafar
#
# ============================================================
# TABLE 83
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['uncle (on fathers\rside)', '.عmmi']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#    uncle (on fathers\rside)         .عmmi
# 0  uncle (on mothers\rside)          xali
# 1                     under          ddaw
# 2                 underwear  lgrşun; slip
# 3                  universe        ddunit
# 4                university       ljamiعa
#
# ============================================================
# TABLE 84
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['waist', 'lHzam']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#             waist                  lHzam
# 0  wait (command)        aġ lHil; bllati
# 1          waiter                lgarşun
# 2        walk (n)                 tanzġa
# 3   walking stick                taġruyt
# 4            wall  agadir; aġrab; ayadir
#
# ============================================================
# TABLE 85
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['welcome back', '.عlslama']
# Shape after cleaning: (36, 2)
#
# First 5 rows:
#           welcome back              .عlslama
# 0               welder  aHddad; amzil; sudur
# 1          well, water              anu; una
# 2  well, water (small)                 tanut
# 3                 west                  lġrb
# 4                 what                  mayd
#
# ============================================================
# TABLE 86
# ============================================================
# Shape: (35, 2) (rows x columns)
# Columns: ['winch', 'lforj']
# Shape after cleaning: (35, 2)
#
# First 5 rows:
#            winch          lforj
# 0           wind    azwu; tirmi
# 1         window  šrjm; talšiwt
# 2  window, small       talkiwit
# 3     windshield        parpriz
# 4           wine           šrab
#
# ============================================================
# TABLE 87
# ============================================================
# Shape: (27, 4) (rows x columns)
# Columns: ['worthless', 'ur su (conj in past)', 'you (F, pl) (indirect', '-awnt']
# Shape after cleaning: (27, 4)
#
# First 5 rows:
#        worthless ur su (conj in past) you (F, pl) (indirect -awnt
# 0            NaN                 walu         obj. pronoun)   NaN
# 1          wound                 ljrH               you (M)    ky
# 2  wrestling (n)               tiġilt               you (M)  kyin
# 3          wrist          tmšt n ufus  you (M) (direct obj.    -k
# 4    writing (n)                tirra              pronoun)   NaN
#
# ============================================================
# TABLE 88
# ============================================================
# Shape: (35, 2) (rows x columns)
# Columns: ['.عada', 'to infect']
# Shape after cleaning: (35, 2)
#
# First 5 rows:
#     .عada         to infect
# 0   .عadi            normal
# 1  .عanwa  wrong (not true)
# 2   .عaqb         to punish
# 3   .عawd         to repeat
# 4   .عawn   to aid; to help
#
# ============================================================
# TABLE 89
# ============================================================
# Shape: (34, 2) (rows x columns)
# Columns: ['.عqql', 'to remember']
# Shape after cleaning: (34, 2)
#
# First 5 rows:
#    .عqql                               to remember
# 0   .عrď                     to exhibit; to recite
# 1   .عrg                                  to sweat
# 2   .عrq  to avoid; to be distant;\rto be far away
# 3  .عrra                                  to strip
# 4  .عrrm         injury (n); to be hurt\rbadly (v)
#
# ============================================================
# TABLE 90
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['abra', 'button']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#      abra                button
# 0   abray  something that hurts
# 1  abrdil           figs, black
# 2  abrdud                  tail
# 3   abrid    road; path; street
# 4   abril                 April
#
# ============================================================
# TABLE 91
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['adrar', 'mountain']
# Shape after cleaning: (38, 2)
#
# First 5 rows:
#     adrar              mountain
# 0  adrġal           blind (adj)
# 1     adu                 smell
# 2   aduar               village
# 3   adur-      do not (command)
# 4      af  to discover; to find
#
# ============================================================
# TABLE 92
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['agg', 'to look out (window)']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#       agg to look out (window)
# 0    aggj              thunder
# 1    aggu            smoke (n)
# 2  aggurn                flour
# 3  aġilas       tiger; cheetah
# 4  agitun                 tent
#
# ============================================================
# TABLE 93
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['aġulid', 'boulder; mountain']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#      aġulid             boulder; mountain
# 0    agulim                  pastry cloth
# 1  agumaţ n                   across from
# 2   agummat  other side (of river,\rroad)
# 3    agunun                          hood
# 4      agur              to be older than
#
# ============================================================
# TABLE 94
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['aHtšun', 'vagina']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#      aHtšun               vagina
# 0     aHuli                sheep
# 1     aHwaš  dance (traditional)
# 2     aHyut                crazy
# 3  ait uxam               family
# 4      ajar               reward
#
# ============================================================
# TABLE 95
# ============================================================
# Shape: (37, 2) (rows x columns)
# Columns: ['alabba n lmnšar', 'sawdust']
# Shape after cleaning: (37, 2)
#
# First 5 rows:
#   alabba n lmnšar           sawdust
# 0             alf             1,000
# 1           alfsa              toad
# 2           alġiġ  mud (really bad)
# 3            alġm             camel
# 4           alġum             camel
#
# ============================================================
# TABLE 96
# ============================================================
# Shape: (41, 2) (rows x columns)
# Columns: ['amazdar', 'person, degraded']
# Shape after cleaning: (41, 2)
#
# First 5 rows:
#       amazdar person, degraded
# 0      amaziġ       berber man
# 1  amd abariq          to slap
# 2        amda  pool (in river)
# 3      amdadi           purple
# 4      amdakl           friend
#
# ============================================================
# TABLE 97
# ============================================================
# Shape: (40, 2) (rows x columns)
# Columns: ['amxmax', 'person, dignified']
# Shape after cleaning: (40, 2)
#
# First 5 rows:
#         amxmax                                  person, dignified
# 0       amxzni                             military men; soldiers
# 1         amya                                            nothing
# 2          amz  to arrest; to capture;\rto catch; to hold; to\...
# 3   amz islman                                            to fish
# 4  amz lintrit                                          to retire
#
# ============================================================
# TABLE 98
# ============================================================
# Shape: (39, 2) (rows x columns)
# Columns: ['anuguţ', 'ram']
# Shape after cleaning: (39, 2)
#
# First 5 rows:
#    anuguţ       ram
# 0   anurz  wish (n)
# 1   anxar      nose
# 2   anzar      rain
# 3   anzay     early
# 4  anzlum      shin
#
# ...
# Shape: (25, 4) (rows x columns)
# Columns: ['to let go of', 'rzm i', 'rzzm i', 'rzmġ i']
# Shape after cleaning: (25, 4)
#
# First 5 rows:
#   to let go of   rzm i   rzzm i   rzmġ i
# 0      to lick     llġ     tllġ    llġ'ġ
# 1       to lie  sHllil  sHillil  sHllilġ
# 2       to lie   skdub    skdub   skdubġ
# 3       to lie  skirks  skirkis   skaksġ
# 4       to lie   sxdid    sxdid   sxdadġ
#
# ============================================================
# TABLE 213
# ============================================================
# Shape: (26, 4) (rows x columns)
# Columns: ['to look', 'raعa', 'traعa', 'raعaġ']
# Shape after cleaning: (26, 4)
#
# First 5 rows:
#          to look   raعa   traعa   raعaġ
# 0        to look   sksu   sksiw   sksuġ
# 1        to look     zr    zrra    zriġ
# 2  to look after    Hďu    Hďďu    Hďiġ
# 3  to look alike  iksil  tiksil  aksulġ
# 4  to look alike   myaġ   tmyaġ  myaġ'ġ
#
# ============================================================
# TABLE 214
# ============================================================
# Shape: (27, 4) (rows x columns)
# Columns: ['to make a woman pregnant\r(man)', 'ssirw', 'ssiriw', 'ssuruġ']
# Shape after cleaning: (27, 4)
#
# First 5 rows:
#   to make a woman pregnant\r(man)  ssirw  ssiriw  ssuruġ
# 0                  to make bigger  sxitr  sxitir  sxatrġ
# 1                    to make deep   zzdr    zzdr   zzdrġ
# 2               to make difficult   ššqu    ššqu   ššqiġ
# 3               to make difficult  ssuعr  ssuعar  ssuعrġ
# 4               to make difficult  swعar  siwعir  suعraġ
#
# ============================================================
# TABLE 215
# ============================================================
# Shape: (22, 4) (rows x columns)
# Columns: ['to make noise (like fingernails\ron a chalkboard)', 'grurs', 'tgrurus', 'grursġ']
# Shape after cleaning: (22, 4)
#
# First 5 rows:
#   to make noise (like fingernails\ron a chalkboard)   grurs  tgrurus   grursġ
# 0                    to make pleasant\rconversation    šršq    šršaq    šršqġ
# 1                                       to make pop    sbďi    sbďay    sbďiġ
# 2                                     to make quiet    sfst    sfsta   sfstiġ
# 3                                     to make ready  siyujd  siyujid  siyujdġ
# 4                     to make someone's nose\rbleed  swunzr  swunzur  swunzrġ
#
# ============================================================
# TABLE 216
# ============================================================
# Shape: (27, 4) (rows x columns)
# Columns: ['to meet', 'jmع d', 'tjmaع d', 'jmعġ d']
# Shape after cleaning: (27, 4)
#
# First 5 rows:
#                     to meet    jmع d   tjmaع d    jmعġ d
# 0  to meet (by coincidence)  mjmaع d  tmjmaع d  mjmaعġ d
# 1     to meet (with people)    mjmaع    tmjmaع    mjmaعġ
# 2                   to melt      fsi      fssi      fsiġ
# 3               to memorize      Hfď     tHfaď      Hfďġ
# 4                 to menace   ggal g  tgalla g  gulliġ g
#
# ============================================================
# TABLE 217
# ============================================================
# Shape: (29, 4) (rows x columns)
# Columns: ['to obey', 'ţaع', 'tţaع', 'ţaعġ']
# Shape after cleaning: (29, 4)
#
# First 5 rows:
#        to obey           ţaع           tţaع             ţaعġ
# 0   to oblige*         bzz'z         tbzzaz           bzz'zġ
# 1  to observe*          laHď         tlaHaď            laHďġ
# 2    to occupy   .عmmr adġar   tعmmar adġar     .عmmrġ adġar
# 3     to occur           jru           tjru  ijra (3rd pers)
# 4    to offend  sxsr lxaţr i  sxsar lxaţr i    sxsrġ lxaţr i
#
# ============================================================
# TABLE 218
# ============================================================
# Shape: (30, 4) (rows x columns)
# Columns: ['to peel', 'qššr', 'tqššar', 'qššrġ']
# Shape after cleaning: (30, 4)
#
# First 5 rows:
#               to peel    qššr   tqššar    qššrġ
# 0    to peel (an egg)     zlm     zlam     zlmġ
# 1  to perform surgery     ftH    tftaH     ftHġ
# 2           to perish  nHufru  tnHufru  nHafraġ
# 3       to photograph     şwr    tşwar     şwrġ
# 4          to pick up     asi     tasi     usiġ
#
# ============================================================
# TABLE 219
# ============================================================
# Shape: (27, 4) (rows x columns)
# Columns: ['to prevent someone from\rdoing something', 'sHrm', 'sHram', 'sHrmġ']
# Shape after cleaning: (27, 4)
#
# First 5 rows:
#   to prevent someone from\rdoing something        sHrm        sHram  \
# 0                                to profit         rbH        trbaH
# 1                                to profit        snfع        snfaع
# 2                              to progress  zayd s dat  tzayd s dat
# 3                              to prohibit         mnع        tmnaع
# 4                              to prohibit        sHrm        sHram
#
#          sHrmġ
# 0         rbHġ
# 1        snfعġ
# 2  zaydġ s dat
# 3         mnعġ
# 4        sHrmġ
#
# ============================================================
# TABLE 220
# ============================================================
# Shape: (30, 4) (rows x columns)
# Columns: ['to reach', 'awď', 'tawď', 'iwďġ']
# Shape after cleaning: (30, 4)
#
# First 5 rows:
#        to reach   awď   tawď   iwďġ
# 0      to reach   lkm  tlkam   lkmġ
# 1       to read    ġr   qqar   ġriġ
# 2    to receive   amz   tamz   umzġ
# 3     to recite  .عrď  tعraď  .عrďġ
# 4  to recognise   akz   takz   ukzġ
#
# ============================================================
# TABLE 221
# ============================================================
# Shape: (29, 4) (rows x columns)
# Columns: ['to resemble', 'iksil', 'tiksil', 'aksulġ']
# Shape after cleaning: (29, 4)
#
# First 5 rows:
#   to resemble        iksil        tiksil        aksulġ
# 0   to reside          zdġ          zddġ         zdġ'ġ
# 1  to resolve        fukku        tfukku        fukkiġ
# 2  to respect        Htarm       tHtaram        Htarmġ
# 3     to rest       swunfu        swunfu       swunfiġ
# 4   to retire  amz lintrit  tamz lintrit  umzġ lintrit
#
# ============================================================
# TABLE 222
# ============================================================
# Shape: (29, 4) (rows x columns)
# Columns: ['to scare', 'siwd', 'ssiwid', 'siwdġ']
# Shape after cleaning: (29, 4)
#
# First 5 rows:
#      to scare  siwd  ssiwid  siwdġ
# 0  to scatter  zllع  tzllaع  zllعġ
# 1    to score  sjjl  tsjjal  sjjlġ
# 2  to scratch   kmz    kmmz   kmzġ
# 3  to scratch   xbš   txbaš   xbšġ
# 4  to scratch   xmz    xmmz   xmzġ
#
# ============================================================
# TABLE 223
# ============================================================
# Shape: (28, 4) (rows x columns)
# Columns: ['to share', 'ssur', 'tsur', 'sarġ']
# Shape after cleaning: (28, 4)
#
# First 5 rows:
#           to share   ssur    tsur    sarġ
# 0         to share   ššur   tššur   ššarġ
# 1       to sharpen   ššwu    ššwu   ššwiġ
# 2         to shave    ġrn    ġrrn    ġrnġ
# 3         to shave   Hssn  tHssan   Hssnġ
# 4  to shell grains  snj"m  snj"am  snj"mġ
#
# ============================================================
# TABLE 224
# ============================================================
# Shape: (29, 4) (rows x columns)
# Columns: ['to skin (i.e. knee, on person )', 'ššnšf', 'ššnšaf', 'ššnšfġ']
# Shape after cleaning: (29, 4)
#
# First 5 rows:
#   to skin (i.e. knee, on person )       ššnšf       ššnšaf       ššnšfġ
# 0                         to slap  amd abariq  tamd abariq  umdġ abariq
# 1                    to slaughter         ġrs         qqrs         ġrsġ
# 2                        to sleep          gn         ggan          gnġ
# 3                        to sleep         gun         ggan         gunġ
# 4               to sleep (babies)       habuš       thabuš       habušġ
#
# ============================================================
# TABLE 225
# ============================================================
# Shape: (28, 4) (rows x columns)
# Columns: ['to spin wool', 'llm', 'tllm', 'llmġ']
# Shape after cleaning: (28, 4)
#
# First 5 rows:
#             to spin wool   llm    tllm             llmġ
# 0                to spit  sufs   sufus            sufsġ
# 1                to spit  sutf   sutuf            sutfġ
# 2               to spoil   xsr    xssr  ixsr (3rd pers)
# 3  to spoil (i.e. plans)  sxsr   sxsar            sxsrġ
# 4              to sprain  lġzm  tlġzam            lġzmġ
#
# ============================================================
# TABLE 226
# ============================================================
# Shape: (26, 4) (rows x columns)
# Columns: ['to step over', 'sġl', 'sġal', 'sġlġ']
# Shape after cleaning: (26, 4)
#
# First 5 rows:
#   to step over   sġl   sġal    sġlġ
# 0     to stick  sslġ  sslaġ  sslġ'ġ
# 1  to still be   sul  tisil    sulġ
# 2     to sting   qqs   tqqs    qqsġ
# 3     to stink  jj"u  tjj"u   jj"iġ
# 4     to stink   xmj  txmaj    xmjġ
#
# ============================================================
# TABLE 227
# ============================================================
# Shape: (30, 4) (rows x columns)
# Columns: ['to swallow', 'zrع', 'zrrع', 'zrعġ']
# Shape after cleaning: (30, 4)
#
# First 5 rows:
#   to swallow   zrع    zrrع    zrعġ
# 0   to swear  ggal  tgalla  gguliġ
# 1   to sweat  .عrg   tعraq   .عrgġ
# 2   to sweep   frď    frrď    frďġ
# 3   to sweep   slH    slaH    slHġ
# 4   to sweep  šţţb  tšţţab   šţţbġ
#
# ============================================================
# TABLE 228
# ============================================================
# Shape: (26, 4) (rows x columns)
# Columns: ['to teach', 'sġr', 'sġra', 'sġriġ']
# Shape after cleaning: (26, 4)
#
# First 5 rows:
#                          to teach         sġr           sġra         sġriġ
# 0  to teach a lesson (figurative)        ššعf          ššعaf         ššعfġ
# 1                         to tear         bbi           tbbi          bbiġ
# 2                        to tease         hdr          thďar          hďrġ
# 3                        to tease       tflla          tflla        tfllaġ
# 4             to telephone (call)  g ttilifun  tgga ttilifun  giġ ttilifun
#
# ============================================================
# TABLE 229
# ============================================================
# Shape: (30, 4) (rows x columns)
# Columns: ['to tie closed', 'jnnţ', 'tjnnaţ', 'jnnţġ']
# Shape after cleaning: (30, 4)
#
# First 5 rows:
#   to tie closed   jnnţ  tjnnaţ   jnnţġ
# 0    to tighten   zyyr  tzyyar   zyyrġ
# 1    to torture  .عddb  tعddab  .عddbġ
# 2      to touch    ggr    tggr    ggrġ
# 3      to touch   ţţas   t'ţas   ţţasġ
# 4      to trace    rsm   trsam    rsmġ
#
# ============================================================
# TABLE 230
# ============================================================
# Shape: (27, 4) (rows x columns)
# Columns: ['to understand', 'fhm', 'tfham', 'fhmġ']
# Shape after cleaning: (27, 4)
#
# First 5 rows:
#        to understand    fhm   tfham    fhmġ
# 0          to unfold    ġrd    qqrd    ġrdġ
# 1          to unlock    rzm    rzzm    rzmġ
# 2          to unpack    xwu    xwwu    xwiġ
# 3           to untie    rzm    rzzm    rzmġ
# 4  to upset (somone)  sqllq  sqllaq  sqllqġ
#
# ============================================================
# TABLE 231
# ============================================================
# Shape: (29, 4) (rows x columns)
# Columns: ['to walk', 'nzuġ', 'nzzġ', "nzġ'ġ"]
# Shape after cleaning: (29, 4)
#
# First 5 rows:
#              to walk  nzuġ                    nzzġ   nzġ'ġ
# 0       to walk (go)   ddu                    tddu    ddiġ
# 1     to walk around   ďur                    tďur    ďurġ
# 2            to want   iri  tiri (to love or like)     riġ
# 3            to warm  ssrġ                   ssrġa  ssrġiġ
# 4  to warm something  sHmu                    sHmu   sHmiġ
#
# ============================================================
# TABLE 232
# ============================================================
# Shape: (22, 4) (rows x columns)
# Columns: ['to wink', 'qqn (conj) tiţ', 'tqqn tiţ', 'qqnġ tiţ']
# Shape after cleaning: (22, 4)
#
# First 5 rows:
#        to wink qqn (conj) tiţ tqqn tiţ qqnġ tiţ
# 0      to wipe            sfď     sffď     sfďġ
# 1  to wipe dry            zwu     zggu     zwiġ
# 2  to wipe off            sfď     sffď     sfďġ
# 3      to wish          tmnna    tmnna   tmnnaġ
# 4    to wither          sllaw   tslliw   sllawġ
#
# ============================================================
# TABLE 233
# ============================================================
# Shape: (42, 4) (rows x columns)
# Columns: ['Abkhazia', 'abxazia', 'Chile', 'ššili']
# Shape after cleaning: (42, 4)
#
# First 5 rows:
#       Abkhazia     abxazia     Chile         ššili
# 0  Afghanistan  afġanistan     China          şşin
# 1          NaN         NaN  Colombia      kulumbia
# 2      Albania     albania       NaN           NaN
# 3          NaN         NaN   Comoros  juzur lqumur
# 4      Algeria      dzayar     Congo        lkunġu
#
# ============================================================
# TABLE 234
# ============================================================
# Shape: (42, 2) (rows x columns)
# Columns: ['Hong Kong', 'hung kung']
# Shape after cleaning: (42, 2)
#
# First 5 rows:
#    Hong Kong  hung kung
# 0    Hungary   hanġarya
# 1    Iceland   aislanda
# 2      India      lhind
# 3  Indonesia  andunisia
# 4       Iran       iran
#
# ============================================================
# TABLE 235
# ============================================================
# Shape: (20, 2) (rows x columns)
# Columns: ['Solomon Islands', 'juzur ssulumun']
# Shape after cleaning: (20, 2)
#
# First 5 rows:
#   Solomon Islands  juzur ssulumun
# 0         Somalia          şşumal
# 1      Somaliland       ard sumal
# 2    South Africa   janub afriqia
# 3     South Korea  kuria aljnubia
# 4           Spain         ispania
#
# ============================================================
# TABLE 236
# ============================================================
# Shape: (8, 2) (rows x columns)
# Columns: ['Uruguay', "l'urugway"]
# Shape after cleaning: (8, 2)
#
# First 5 rows:
#         Uruguay   l'urugway
# 0    Uzbekistan  uzbakistan
# 1       Vanuatu      vanatu
# 2  Vatican City    lvatigan
# 3     Venezuela    vinzuila
# 4       Vietman     lvitnam
#
# ============================================================
# TABLE 237
# ============================================================
# Shape: (19, 3) (rows x columns)
# Columns: ['Phrase', 'English translation', 'When used']
# Shape after cleaning: (19, 3)
#
# First 5 rows:
#          Phrase                                English translation  \
# 0     bismillah                                 in the name of God
# 1     llahiعawn                                       God help you
# 2   llah isllim                                   God help you too
# 3          bşHa                                     To your health
# 4  llahiعtikşHa  May God give you health\rtoo; congratulations;...
#
#                                            When used
# 0        before eating; before doing almost anything
# 1      hello; good bye; literally "may God help you"
# 2                              response to llahiعawn
# 3  to people who are eating; wearing new\rclothes...
# 4  response to bşHa; said to someone who cooks\ra...
#
# ============================================================
# TABLE 238
# ============================================================
# Shape: (11, 3) (rows x columns)
# Columns: ['llah irHam lwaldin', 'God bless your parents', 'used to thank someone for something big']
# Shape after cleaning: (11, 3)
#
# First 5 rows:
#         llah irHam lwaldin                      God bless your parents  \
# 0        llah inعl lwaldik                      God curse your parents
# 1          ad ig arrbi str                     May God cover your sins
# 2             ad iعfu rrbi                   May God repent your\rsins
# 3          ad iawi rrbi...                            May God bring...
# 4  ak/akm yari rrbi I lbla  May God put all\rwickedness away from\ryou
#
#              used to thank someone for something big
# 0  big insult; used if someone does something\rre...
# 1  used to say good bye; can also be used to\rmea...
# 2  said to someone who is sick or who lights your...
# 3  said when you wish for something good to\rhapp...
# 4  can be used anytime you talk about bad things\...

# %%
lengths = []
for t in all_tables:
    lengths.append(len(t.columns))

print(lengths)
# Out:
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 2, 2, 3, 3]

# %%
for i, t in enumerate(all_tables):
    print(([i, len(t.columns)], t.iloc[-1].to_numpy()))
# Out:
# ([0, 2], array(['a lot (number)', '.عtan; gudin'], dtype=object))
# ([1, 2], array(['Allah', 'rbbi'], dtype=object))
# ([2, 2], array(['art', 'Lfnn'], dtype=object))
# ([3, 2], array(['bangles', 'dama'], dtype=object))
# ([4, 2], array(['beetle', 'Abxxuš'], dtype=object))
# ([5, 2], array(['blister (n)', 'tilfxt'], dtype=object))
# ([6, 2], array(['bracelet', 'azbi; azvi; tazvit;'], dtype=object))
# ([7, 2], array(['bubble (noun)', 'tabuwlt; tibiwlt'], dtype=object))
# ([8, 2], array(['calf (cow)', 'Taعjliyt'], dtype=object))
# ([9, 2], array(['cedar', 'larz'], dtype=object))
# ([10, 2], array(['church', 'lkanisa'], dtype=object))
# ([11, 2], array(['come here!', 'addud'], dtype=object))
# ([12, 2], array(['cough (n)', 'takuHut; tusut'], dtype=object))
# ([13, 2], array(['curry (n)', 'lkurnb'], dtype=object))
# ([14, 2], array(['director', 'lmudir'], dtype=object))
# ([15, 2], array(['drawing of water', 'igm'], dtype=object))
# ([16, 2], array(['eggs', 'tiglay'], dtype=object))
# ([17, 2], array(['extremist', 'mutatarif'], dtype=object))
# ([18, 2], array(['fence', 'lHdd; tigitt'], dtype=object))
# ([19, 2], array(['flat portable surface\rused for flattening\rbread', 'aglim'],
#       dtype=object))
# ([20, 2], array(['form (for mud\rconstruction)', 'ttabut'], dtype=object))
# ([21, 2], array(['girl', 'tarbat'], dtype=object))
# ([22, 2], array(['grave (n)', 'asmdl; lqbr; timdlt'], dtype=object))
# ([23, 2], array(['handle, axe', 'tirgxt; trkxt'], dtype=object))
# ([24, 2], array(['here it is', 'han'], dtype=object))
# ([25, 2], array(['housedress', 'pijama'], dtype=object))
# ([26, 2], array(['inspector', 'lmuftiš'], dtype=object))
# ([27, 2], array(['Jews', 'l-yahud; udayn'], dtype=object))
# ([28, 2], array(['leaf', 'ifrr'], dtype=object))
# ([29, 2], array(['lock (n)', 'lqfl'], dtype=object))
# ([30, 2], array(['mathamatics', 'rryadiat'], dtype=object))
# ([31, 2], array(['metal, a useless', 'aqzdir'], dtype=object))
# ([32, 2], array(['Moroccans', 'imaġribin'], dtype=object))
# ([33, 2], array(['nationality', 'ljinsia'], dtype=object))
# ([34, 4], array(['nostalgia (for)', 'taġufi', nan, nan], dtype=object))
# ([35, 2], array(['panther*', 'lfahd'], dtype=object))
# ([36, 2], array(['penis (slang) (least\rshocking)', 'lqlm'], dtype=object))
# ([37, 2], array(['phlegm', 'axlul; axnsir'], dtype=object))
# ([38, 2], array(['plowing, by hand', 'lqlib; tukurt'], dtype=object))
# ([39, 2], array(['press (n)', 'zzyyar'], dtype=object))
# ([40, 2], array(['pus', 'arşd; nšl'], dtype=object))
# ([41, 2], array(['relatives', 'tagmat; taymat'], dtype=object))
# ([42, 2], array(['rosemary', 'asir'], dtype=object))
# ([43, 2], array(['science', 'lعulum'], dtype=object))
# ([44, 2], array(['sheepskin (uncut)', 'abďďan'], dtype=object))
# ([45, 2], array(['singer*', 'lmuġnni'], dtype=object))
# ([46, 2], array(['snot', 'axansir'], dtype=object))
# ([47, 2], array(['souvenir', 'dikra'], dtype=object))
# ([48, 2], array(['steel', 'lhnt'], dtype=object))
# ([49, 2], array(['subject', 'lmuďuع'], dtype=object))
# ([50, 2], array(['teacher', 'lmuعlim/talmuعlimt;\rustad/ustada'], dtype=object))
# ([51, 2], array(['them (M)', 'nitni'], dtype=object))
# ([52, 2], array(['Thursday', 'lxmis'], dtype=object))
# ([53, 2], array(['to answer', 'jawb; wajb'], dtype=object))
# ([54, 2], array(['to be born', 'lal'], dtype=object))
# ([55, 2], array(['to be difficult', 'šqu; wعr'], dtype=object))
# ([56, 2], array(['to be ill', 'mrď'], dtype=object))
# ([57, 2], array(['to be part of', 'umu'], dtype=object))
# ([58, 2], array(['to be straight', 'nm'], dtype=object))
# ([59, 2], array(['to bend (something)', 'sknu'], dtype=object))
# ([60, 2], array(['to catch', 'amz'], dtype=object))
# ([61, 2], array(['to cough', 'skuHu; usu'], dtype=object))
# ([62, 2], array(['to disappear', 'ašk; ġbr; ġyyb'], dtype=object))
# ([63, 2], array(['to embrace Islam', 'slm'], dtype=object))
# ([64, 2], array(['to father children', 'aru'], dtype=object))
# ([65, 2], array(['to get down', 'ggz'], dtype=object))
# ([66, 2], array(['to hand', 'k'], dtype=object))
# ([67, 4], array(['to hurt (be painful)', 'nġ (conj. as reflexive', nan, nan],
#       dtype=object))
# ([68, 2], array(['to lower', 'naqs; sigz'], dtype=object))
# ([69, 2], array(['to make something\rgo together', 'smun'], dtype=object))
# ([70, 2], array(['to need', 'Htadja; xssa'], dtype=object))
# ([71, 2], array(['to pop something', 'sbbďi'], dtype=object))
# ([72, 2], array(['to record', 'sjjl'], dtype=object))
# ([73, 2], array(['to rush', 'sddrf'], dtype=object))
# ([74, 2], array(['to shut up', 'fst'], dtype=object))
# ([75, 2], array(['to spray (insecticide)', 'şuţ'], dtype=object))
# ([76, 2], array(['to sunbathe', 'rġ tafuyt'], dtype=object))
# ([77, 2], array(['to throw out', 'gr s'], dtype=object))
# ([78, 2], array(['to use incense to\rmake smoke', 'bxxr'], dtype=object))
# ([79, 2], array(['to worry', 'qllq'], dtype=object))
# ([80, 2], array(['trap', 'qrra; taqbut'], dtype=object))
# ([81, 2], array(['umbrella', 'lmďl; mďlla'], dtype=object))
# ([82, 2], array(['vulva', 'abši'], dtype=object))
# ([83, 2], array(['welcome', 'marhaba'], dtype=object))
# ([84, 2], array(['wildlife', 'luHuš'], dtype=object))
# ([85, 2], array(['worms', 'izrman; tiwkkiw'], dtype=object))
# ([86, 4], array(['pronoun)', nan, 'zoo', 'lHadiqa n lHayawan'], dtype=object))
# ([87, 2], array(['.عniġ', 'I think so; maybe;\rperhaps; probably'], dtype=object))
# ([88, 2], array(['ablxir', 'wild boar'], dtype=object))
# ([89, 2], array(['adr i', 'to cover (a dead\rbody)'], dtype=object))
# ([90, 2], array(['agdid', 'bird'], dtype=object))
# ([91, 2], array(['aġul tiġurdin', 'to reverse'], dtype=object))
# ([92, 2], array(['ahssan', 'barber'], dtype=object))
# ([93, 2], array(['al', 'to cry; to weep'], dtype=object))
# ([94, 2], array(['amarš', 'start of motor (n)'], dtype=object))
# ([95, 2], array(['amwur', 'scythe'], dtype=object))
# ([96, 2], array(['anuguď', 'sheep'], dtype=object))
# ([97, 2], array(['ariaz', 'man'], dtype=object))
# ([98, 2], array(['asggas', 'year'], dtype=object))
# ([99, 2], array(['asnsar', 'necklace'], dtype=object))
# ([100, 2], array(['avray', 'something that hurts\r(on body)'], dtype=object))
# ([101, 2], array(['axdil', 'belly; stomach'], dtype=object))
# ([102, 2], array(['azalim', 'onion'], dtype=object))
# ([103, 2], array(['aعskri', 'military; soldier'], dtype=object))
# ([104, 2], array(['bllati', 'wait (command)'], dtype=object))
# ([105, 2], array(['bxxr', 'to fumigate; to use\rincense to make\rsmoke'],
#       dtype=object))
# ([106, 2], array(['ddifع', 'defense (soccer)'], dtype=object))
# ([107, 2], array(['dġik', 'now'], dtype=object))
# ([108, 2], array(['duhdu', 'to get dizzy'], dtype=object))
# ([109, 2], array(['flan', 'someone'], dtype=object))
# ([110, 2], array(['g ddrع', 'to make something\rhappen, by force'], dtype=object))
# ([111, 2], array(['ġm', 'to dye'], dtype=object))
# ([112, 2], array(['ġušu', 'to cheat'], dtype=object))
# ([113, 2], array(['Hkam', 'to sentence (court)'], dtype=object))
# ([114, 2], array(['Hyyr', 'to be anxious'], dtype=object))
# ([115, 2], array(['ifasn', 'arms; hands'], dtype=object))
# ([116, 2], array(['igllin', 'poor thing'], dtype=object))
# ([117, 2], array(['ikmz', 'finger, thumb'], dtype=object))
# ([118, 2], array(['imriry', 'stack (n)'], dtype=object))
# ([119, 2], array(['iqrruyn', 'horns (animal)'], dtype=object))
# ([120, 2], array(['iskr', 'toenail'], dtype=object))
# ([121, 2], array(['iwatu*', 'self'], dtype=object))
# ([122, 2], array(['izlan', 'songs'], dtype=object))
# ([123, 2], array(['jjuع', 'famine*; greed'], dtype=object))
# ([124, 2], array(['kďu', 'to smell'], dtype=object))
# ([125, 4], array(['krfs', 'to mess up', 'lahdaf', 'goals'], dtype=object))
# ([126, 2], array(['lbHar l-abyad l-\rmutawassit', 'Meditteranean Sea'], dtype=object))
# ([127, 2], array(['lfamila', 'relative'], dtype=object))
# ([128, 2], array(['lfurmasyun', 'training'], dtype=object))
# ([129, 2], array(['lhawa', 'air; breeze in house'], dtype=object))
# ([130, 2], array(['lHwayj', 'clothes; things'], dtype=object))
# ([131, 2], array(['ljir', 'plaster'], dtype=object))
# ([132, 2], array(['lkrik', 'jack, tire'], dtype=object))
# ([133, 2], array(['lmal', 'sheep and goats'], dtype=object))
# ([134, 2], array(['lmjarib', 'stairs'], dtype=object))
# ([135, 2], array(['lmswak', 'toothpick'], dtype=object))
# ([136, 2], array(['lmعllm', 'craftsperson'], dtype=object))
# ([137, 2], array(['lqrfa', 'cinnamon'], dtype=object))
# ([138, 2], array(['lward', 'rose (flower)'], dtype=object))
# ([139, 2], array(['lعaşima', 'capital (n)'], dtype=object))
# ([140, 2], array(['mamnuع', 'forbidden'], dtype=object))
# ([141, 2], array(['mġi', 'to sprout'], dtype=object))
# ([142, 2], array(['mnu', 'to look in mirror'], dtype=object))
# ([143, 2], array(['murabbaع', 'square (geometry)'], dtype=object))
# ([144, 4], array(['narzm', 'to be loose', 'nkin', 'I'], dtype=object))
# ([145, 2], array(['-nsn', 'their (M)'], dtype=object))
# ([146, 2], array(['qillu', 'corn'], dtype=object))
# ([147, 2], array(['qşşr', 'to flirt'], dtype=object))
# ([148, 2], array(['rjij', 'to convulse; to\rtremble'], dtype=object))
# ([149, 2], array(['rsa', 'to stop doing\rsomething'], dtype=object))
# ([150, 2], array(['saHafi', 'journalist'], dtype=object))
# ([151, 2], array(['sbdd', 'to make stop'], dtype=object))
# ([152, 2], array(['sfliliy', 'to glean; to shine\r(sun)'], dtype=object))
# ([153, 2], array(['šhriya', 'salary'], dtype=object))
# ([154, 2], array(['siuġ', 'to make graze'], dtype=object))
# ([155, 2], array(['slip', 'panties; underwear'], dtype=object))
# ([156, 2], array(['snnd', 'to lie down'], dtype=object))
# ([157, 2], array(['s-sail', 'liquid*'], dtype=object))
# ([158, 2], array(['ssird', 'to bathe; to clean'], dtype=object))
# ([159, 2], array(['ššţ', 'to slip'], dtype=object))
# ([160, 2], array(['sti', 'to choose; to\rseparate; to be\rseparate'], dtype=object))
# ([161, 2], array(['šuwaya', 'brochette racks; grill'], dtype=object))
# ([162, 2], array(['šعl', 'to light*; to turn on'], dtype=object))
# ([163, 2], array(['tafllaHt', 'agriculture'], dtype=object))
# ([164, 2], array(['taguni', 'sleep'], dtype=object))
# ([165, 4], array(['takula', 'mask of pregnancy', 'tamgurt', 'scythe'], dtype=object))
# ([166, 2], array(['taqfift', 'basket'], dtype=object))
# ([167, 2], array(['taslmia', 'baby'], dtype=object))
# ([168, 2], array(['tawtult', 'common hare; rabbit'], dtype=object))
# ([169, 2], array(['taعjliyt', 'calf (cow)'], dtype=object))
# ([170, 2], array(['tifinaġ', 'alphabet, Tamazight'], dtype=object))
# ([171, 2], array(['tiHwarin', 'bowls'], dtype=object))
# ([172, 2], array(['tinnġ', 'ours'], dtype=object))
# ([173, 2], array(['tislit n iyjnna', 'rainbow'], dtype=object))
# ([174, 2], array(['tiعzzit', 'bravery'], dtype=object))
# ([175, 2], array(['triţwar', 'curb'], dtype=object))
# ([176, 2], array(['ţţmع', 'greed'], dtype=object))
# ([177, 2], array(['tuxmas', 'teeth'], dtype=object))
# ([178, 2], array(['unfus', 'air; breath (n)'], dtype=object))
# ([179, 2], array(['ut (conj) s rrkl', 'to kick'], dtype=object))
# ([180, 2], array(['watx', 'this'], dtype=object))
# ([181, 2], array(['xllf',
#        'to multiply (be fruitful)\r(agriculture); to\rchange (clothes); to\rshift (car gears)'],
#       dtype=object))
# ([182, 4], array(['yan', '1', 'zdr', 'to be deep'], dtype=object))
# ([183, 4], array([nan, 'to visit (saint)', nan, nan], dtype=object))
# ([184, 4], array(['to applaud', 'ut rršš', 'kkat rršš', 'wtġ rršš'], dtype=object))
# ([185, 4], array(['to be a lot', '.عtu', '.عttu', '.عtiġ'], dtype=object))
# ([186, 4], array(['to be calm', 'hddn', 'thddan', 'hddnġ'], dtype=object))
# ([187, 4], array(['to be curvy', 'frġ', 'frrġ', 'frrq'], dtype=object))
# ([188, 4], array(['to be fast', 'srbi', 'tsrbay', 'srbiġ'], dtype=object))
# ([189, 4], array(['to be hot', 'Hmu', 'tHmu', 'Hmiġ'], dtype=object))
# ([190, 4], array(['to be lost in thought', 'xmm', 'txmmam', "xmm'mġ"], dtype=object))
# ([191, 4], array(['to be poor', 'dعf', 'tďعaf', 'ďعfġ'], dtype=object))
# ([192, 4], array(['to be sifted', 'afuf', 'tifif', 'afufġ'], dtype=object))
# ([193, 4], array(['to be upset', 'qllq', 'tqllaq', 'qllqġ'], dtype=object))
# ([194, 4], array(['to benefit from', 'snfع', 'snfaع', 'snfعġ'], dtype=object))
# ([195, 4], array(['to breathe', 'sunfs', 'sunfus', 'sunfsġ'], dtype=object))
# ([196, 4], array(['to change (money)', 'şrrf', 'tşrraf', 'şrrfġ'], dtype=object))
# ([197, 4], array(['to confuse', 'xrbq', 'txrbaq', 'xrbqġ'], dtype=object))
# ([198, 4], array(['to cut (grass)', 'Hšš', 'tHšaš', 'Hššiġ'], dtype=object))
# ([199, 4], array(['to disappear', 'ašk', 'taška', 'uškiġ'], dtype=object))
# ([200, 4], array(['to dress', 'ls', 'lssa', 'lsiġ'], dtype=object))
# ([201, 4], array(['to enroll', 'qyyd', 'tqyyad', 'qyydġ'], dtype=object))
# ([202, 4], array(['to fake', 'zwwr', 'tzwwar', 'zwwrġ'], dtype=object))
# ([203, 4], array(['to fit', 'ga', 'tgga', 'giġ'], dtype=object))
# ([204, 4], array(['to gain', 'rbH', 'trbaH', 'rbHġ'], dtype=object))
# ([205, 4], array(['to give permission', 'k ladn', 'akka ladn', 'kiġ ladn'],
#       dtype=object))
# ([206, 4], array(['to guard', 'Hďu', 'Hţţu', 'Hďiġ'], dtype=object))
# ([207, 4], array(['to have sex (euphemism)', 'jamع', 'tjamaع', 'jamعġ'], dtype=object))
# ([208, 4], array(['to husk', 'zlm', 'zllm', 'zlmġ'], dtype=object))
# ([209, 4], array(['to kick', 'ut (conj) s rrkl', 'kat s rrkl', 'utġ s rrkl'],
#       dtype=object))
# ([210, 4], array(['to let go (of something)', 'zdu', 'zddu', 'zdiġ'], dtype=object))
# ([211, 4], array(['to long for', 'tnġa* taġufi n', 'nqqa* tġufi n', 'tnġayi tġufi'],
#       dtype=object))
# ([212, 4], array(['to make', 'Hiyya', 'tHiyya', 'Hiyyaġ'], dtype=object))
# ([213, 4], array(['to make noise', 'sďďع', 'tsďďaع', 'sďďع'], dtype=object))
# ([214, 4], array(['to mediate', 'şalH', 'tşalaH', 'şalHġ'], dtype=object))
# ([215, 4], array(['to need', 'xssa (reflexive)', 'ttxşşa', 'ixşşay-i'], dtype=object))
# ([216, 4], array(['to pay attention', 'rar lbal', 'trara lbal', 'ruriġ lbal'],
#       dtype=object))
# ([217, 4], array(['to prevent', 'mnع', 'tmnaع', 'mnعġ'], dtype=object))
# ([218, 4], array(['to rape', 'ġtaşb', 'tġtaşab', 'ġtaşbġ'], dtype=object))
# ([219, 4], array(['to resemble', 'aġ', 'taġ', "aġ'ġ"], dtype=object))
# ([220, 4], array(['to say', 'ini', 'tini', 'nniġ'], dtype=object))
# ([221, 4], array(['to shake hands with/greet\reach other', 'msllam', 'tmsllam',
#        'msllamġ'], dtype=object))
# ([222, 4], array(['to skin', 'uzu', 'tuzu', 'azuġ'], dtype=object))
# ([223, 4], array(['to spin', "ml'lly", "tml'llay", "ml'llyġ"], dtype=object))
# ([224, 4], array(['to step on', 'akl xf', 'takl xf', 'uklġ xf'], dtype=object))
# ([225, 4], array(['to swallow', 'lqm', 'lqqm', 'lqmġ'], dtype=object))
# ([226, 4], array(['to teach', '.عllm', 'tعllam', '.عllmġ'], dtype=object))
# ([227, 4], array(['to tie (i.e. cow)', 'krf', 'krrf', 'krfġ'], dtype=object))
# ([228, 4], array(['to type', 'ara', 'tara', 'araġ'], dtype=object))
# ([229, 4], array(['to wake up (open eyes)', 'fafa', 'tfafa', 'fafaġ'], dtype=object))
# ([230, 4], array(['to wink', 'ġmz', 'tġmaz', 'ġmzġ'], dtype=object))
# ([231, 4], array(['to yell', 'sġuy', 'sġuyyu', 'sġuyġ'], dtype=object))
# ([232, 4], array([nan, nan, 'Honduras', 'alhinduras'], dtype=object))
# ([233, 2], array(['Mongolia', 'manġuliya'], dtype=object))
# ([234, 2], array(['Tunisia', 'tuns'], dtype=object))
# ([235, 2], array(['Zimbabwe', 'zimbabway'], dtype=object))
# ([236, 3], array(['rrbi lman', 'May God send peace',
#        'said to someone who is traveling; when talking\rabout something that is supposed to happen in\rthe future'],
#       dtype=object))
# ([237, 3], array(['mš iktab (rrbi)', 'if it is written',
#        'used to talk about future plans'], dtype=object))

# %%
print(all_tables[232].iloc[-1].to_numpy())
# Out:
# [nan nan 'Honduras' 'alhinduras']

# %%
for i, t in enumerate(all_tables):
    #display the index of the table if it contains na or not
    print(i) if t.isna().any().to_numpy().any() else None
# Out:
# 34
# 52
# 67
# 68
# 86
# 125
# 144
# 165
# 182
# 183
# 232

# %%
# Corrected section boundaries based on your data
sections = {
    'english_tamazight': {'start': 0, 'end': 86, 'columns': 2, 'has_header': False},
    'tamazight_english': {'start': 87, 'end': 183, 'columns': 2, 'has_header': False},
    'verbs': {'start': 184, 'end': 231, 'columns': 4, 'has_header': True},
    'countries': {'start': 232, 'end': 235, 'columns': 2, 'has_header': False},
    'god_phrases': {'start': 236, 'end': 237, 'columns': 3, 'has_header': True}
}

# Tables that need to be split (4 columns -> two 2-column tables)
tables_to_split = [34, 67, 86, 125, 144, 165, 182, 183, 232]

print("Corrected Section Analysis:")
for section_name, info in sections.items():
    count = info['end'] - info['start'] + 1
    print(f"{section_name}: Tables {info['start']}-{info['end']} ({count} tables, {info['columns']} columns)")

print(f"\nTables to split: {tables_to_split}")
print(f"Original table count: {len(all_tables)}")
# Out:
# Corrected Section Analysis:
# english_tamazight: Tables 0-86 (87 tables, 2 columns)
# tamazight_english: Tables 87-183 (97 tables, 2 columns)
# verbs: Tables 184-231 (48 tables, 4 columns)
# countries: Tables 232-235 (4 tables, 2 columns)
# god_phrases: Tables 236-237 (2 tables, 3 columns)
#
# Tables to split: [34, 67, 86, 125, 144, 165, 182, 183, 232]
# Original table count: 238

# %%
# Function to split 4-column tables into two 2-column tables
def split_table(table, table_idx):
    """Split a 4-column table into two 2-column tables"""
    if table.shape[1] >= 4:
        # Split into first 2 columns and last 2 columns
        table1 = table.iloc[:, :2].copy()
        table2 = table.iloc[:, 2:4].copy()
        
        print(f"  Split table {table_idx}: {table.shape} -> {table1.shape} + {table2.shape}")
        return [table1, table2]
    else:
        print(f"  Warning: Table {table_idx} has only {table.shape[1]} columns, cannot split")
        return [table]

# Create new list with split tables
split_tables = []
split_mapping = {}  # Track original index to new indices

for i, table in enumerate(all_tables):
    if i in tables_to_split:
        split_result = split_table(table, i)
        start_idx = len(split_tables)
        split_tables.extend(split_result)
        split_mapping[i] = list(range(start_idx, len(split_tables)))
        print(f"Table {i} split into indices {split_mapping[i]}")
    else:
        split_tables.append(table)
        split_mapping[i] = [len(split_tables) - 1]

print(f"\nTotal tables after splitting: {len(split_tables)} (expected 247)")
# Out:
#   Split table 34: (54, 4) -> (54, 2) + (54, 2)
# Table 34 split into indices [34, 35]
#   Split table 67: (53, 4) -> (53, 2) + (53, 2)
# Table 67 split into indices [68, 69]
#   Split table 86: (27, 4) -> (27, 2) + (27, 2)
# Table 86 split into indices [88, 89]
#   Split table 125: (43, 4) -> (43, 2) + (43, 2)
# Table 125 split into indices [128, 129]
#   Split table 144: (44, 4) -> (44, 2) + (44, 2)
# Table 144 split into indices [148, 149]
#   Split table 165: (43, 4) -> (43, 2) + (43, 2)
# Table 165 split into indices [170, 171]
#   Split table 182: (43, 4) -> (43, 2) + (43, 2)
# Table 182 split into indices [188, 189]
#   Split table 183: (42, 4) -> (42, 2) + (42, 2)
# Table 183 split into indices [190, 191]
#   Split table 232: (42, 4) -> (42, 2) + (42, 2)
# Table 232 split into indices [240, 241]
#
# Total tables after splitting: 247 (expected 247)

# %%
# Clean all tables and remove any rows with NaN/null values
cleaned_tables = []

for i, table in enumerate(split_tables):
    # Basic cleaning
    cleaned = table.dropna(how='all').dropna(axis=1, how='all')
    
    # Drop any rows that contain NaN values
    cleaned = cleaned.dropna()
    
    # Remove empty string rows if any
    if len(cleaned.columns) > 0:
        # Check if all values in a row are empty strings
        mask = ~(cleaned == '').all(axis=1)
        cleaned = cleaned[mask]
    
    cleaned_tables.append(cleaned)
    
    if i < 10 or len(cleaned) == 0:  # Show first 10 and any empty tables
        print(f"Table {i}: {table.shape} -> {cleaned.shape}")

print(f"\nCleaned {len(cleaned_tables)} tables")

# Update all_tables reference
all_tables = cleaned_tables
# Out:
# Table 0: (38, 2) -> (38, 2)
# Table 1: (39, 2) -> (39, 2)
# Table 2: (40, 2) -> (40, 2)
# Table 3: (40, 2) -> (40, 2)
# Table 4: (39, 2) -> (39, 2)
# Table 5: (39, 2) -> (39, 2)
# Table 6: (38, 2) -> (38, 2)
# Table 7: (38, 2) -> (38, 2)
# Table 8: (37, 2) -> (37, 2)
# Table 9: (36, 2) -> (36, 2)
#
# Cleaned 247 tables

# %%
for i, t in enumerate(all_tables):
    print(([i, len(t.columns)], t.iloc[-1].to_numpy()))
# Out:
# ([0, 2], array(['a lot (number)', '.عtan; gudin'], dtype=object))
# ([1, 2], array(['Allah', 'rbbi'], dtype=object))
# ([2, 2], array(['art', 'Lfnn'], dtype=object))
# ([3, 2], array(['bangles', 'dama'], dtype=object))
# ([4, 2], array(['beetle', 'Abxxuš'], dtype=object))
# ([5, 2], array(['blister (n)', 'tilfxt'], dtype=object))
# ([6, 2], array(['bracelet', 'azbi; azvi; tazvit;'], dtype=object))
# ([7, 2], array(['bubble (noun)', 'tabuwlt; tibiwlt'], dtype=object))
# ([8, 2], array(['calf (cow)', 'Taعjliyt'], dtype=object))
# ([9, 2], array(['cedar', 'larz'], dtype=object))
# ([10, 2], array(['church', 'lkanisa'], dtype=object))
# ([11, 2], array(['come here!', 'addud'], dtype=object))
# ([12, 2], array(['cough (n)', 'takuHut; tusut'], dtype=object))
# ([13, 2], array(['curry (n)', 'lkurnb'], dtype=object))
# ([14, 2], array(['director', 'lmudir'], dtype=object))
# ([15, 2], array(['drawing of water', 'igm'], dtype=object))
# ([16, 2], array(['eggs', 'tiglay'], dtype=object))
# ([17, 2], array(['extremist', 'mutatarif'], dtype=object))
# ([18, 2], array(['fence', 'lHdd; tigitt'], dtype=object))
# ([19, 2], array(['flat portable surface\rused for flattening\rbread', 'aglim'],
#       dtype=object))
# ([20, 2], array(['form (for mud\rconstruction)', 'ttabut'], dtype=object))
# ([21, 2], array(['girl', 'tarbat'], dtype=object))
# ([22, 2], array(['grave (n)', 'asmdl; lqbr; timdlt'], dtype=object))
# ([23, 2], array(['handle, axe', 'tirgxt; trkxt'], dtype=object))
# ([24, 2], array(['here it is', 'han'], dtype=object))
# ([25, 2], array(['housedress', 'pijama'], dtype=object))
# ([26, 2], array(['inspector', 'lmuftiš'], dtype=object))
# ([27, 2], array(['Jews', 'l-yahud; udayn'], dtype=object))
# ([28, 2], array(['leaf', 'ifrr'], dtype=object))
# ([29, 2], array(['lock (n)', 'lqfl'], dtype=object))
# ([30, 2], array(['mathamatics', 'rryadiat'], dtype=object))
# ([31, 2], array(['metal, a useless', 'aqzdir'], dtype=object))
# ([32, 2], array(['Moroccans', 'imaġribin'], dtype=object))
# ([33, 2], array(['nationality', 'ljinsia'], dtype=object))
# ([34, 2], array(['nostalgia (for)', 'taġufi'], dtype=object))
# ([35, 2], array(['only', 'day'], dtype=object))
# ([36, 2], array(['panther*', 'lfahd'], dtype=object))
# ([37, 2], array(['penis (slang) (least\rshocking)', 'lqlm'], dtype=object))
# ([38, 2], array(['phlegm', 'axlul; axnsir'], dtype=object))
# ([39, 2], array(['plowing, by hand', 'lqlib; tukurt'], dtype=object))
# ([40, 2], array(['press (n)', 'zzyyar'], dtype=object))
# ([41, 2], array(['pus', 'arşd; nšl'], dtype=object))
# ([42, 2], array(['relatives', 'tagmat; taymat'], dtype=object))
# ([43, 2], array(['rosemary', 'asir'], dtype=object))
# ([44, 2], array(['science', 'lعulum'], dtype=object))
# ([45, 2], array(['sheepskin (uncut)', 'abďďan'], dtype=object))
# ([46, 2], array(['singer*', 'lmuġnni'], dtype=object))
# ([47, 2], array(['snot', 'axansir'], dtype=object))
# ([48, 2], array(['souvenir', 'dikra'], dtype=object))
# ([49, 2], array(['steel', 'lhnt'], dtype=object))
# ([50, 2], array(['subject', 'lmuďuع'], dtype=object))
# ([51, 2], array(['teacher', 'lmuعlim/talmuعlimt;\rustad/ustada'], dtype=object))
# ([52, 2], array(['them (M)', 'nitni'], dtype=object))
# ([53, 2], array(['Thursday', 'lxmis'], dtype=object))
# ([54, 2], array(['to answer', 'jawb; wajb'], dtype=object))
# ([55, 2], array(['to be born', 'lal'], dtype=object))
# ([56, 2], array(['to be difficult', 'šqu; wعr'], dtype=object))
# ([57, 2], array(['to be ill', 'mrď'], dtype=object))
# ([58, 2], array(['to be part of', 'umu'], dtype=object))
# ([59, 2], array(['to be straight', 'nm'], dtype=object))
# ([60, 2], array(['to bend (something)', 'sknu'], dtype=object))
# ([61, 2], array(['to catch', 'amz'], dtype=object))
# ([62, 2], array(['to cough', 'skuHu; usu'], dtype=object))
# ([63, 2], array(['to disappear', 'ašk; ġbr; ġyyb'], dtype=object))
# ([64, 2], array(['to embrace Islam', 'slm'], dtype=object))
# ([65, 2], array(['to father children', 'aru'], dtype=object))
# ([66, 2], array(['to get down', 'ggz'], dtype=object))
# ([67, 2], array(['to hand', 'k'], dtype=object))
# ([68, 2], array(['to hurt (be painful)', 'nġ (conj. as reflexive'], dtype=object))
# ([69, 2], array(['to leave', 'adj; zri'], dtype=object))
# ([70, 2], array(['to lower', 'naqs; sigz'], dtype=object))
# ([71, 2], array(['to make something\rgo together', 'smun'], dtype=object))
# ([72, 2], array(['to need', 'Htadja; xssa'], dtype=object))
# ([73, 2], array(['to pop something', 'sbbďi'], dtype=object))
# ([74, 2], array(['to record', 'sjjl'], dtype=object))
# ([75, 2], array(['to rush', 'sddrf'], dtype=object))
# ([76, 2], array(['to shut up', 'fst'], dtype=object))
# ([77, 2], array(['to spray (insecticide)', 'şuţ'], dtype=object))
# ([78, 2], array(['to sunbathe', 'rġ tafuyt'], dtype=object))
# ([79, 2], array(['to throw out', 'gr s'], dtype=object))
# ([80, 2], array(['to use incense to\rmake smoke', 'bxxr'], dtype=object))
# ([81, 2], array(['to worry', 'qllq'], dtype=object))
# ([82, 2], array(['trap', 'qrra; taqbut'], dtype=object))
# ([83, 2], array(['umbrella', 'lmďl; mďlla'], dtype=object))
# ([84, 2], array(['vulva', 'abši'], dtype=object))
# ([85, 2], array(['welcome', 'marhaba'], dtype=object))
# ([86, 2], array(['wildlife', 'luHuš'], dtype=object))
# ([87, 2], array(['worms', 'izrman; tiwkkiw'], dtype=object))
# ([88, 2], array(['you (F, pl) (direct obj.', '-knt'], dtype=object))
# ([89, 2], array(['zoo', 'lHadiqa n lHayawan'], dtype=object))
# ([90, 2], array(['.عniġ', 'I think so; maybe;\rperhaps; probably'], dtype=object))
# ([91, 2], array(['ablxir', 'wild boar'], dtype=object))
# ([92, 2], array(['adr i', 'to cover (a dead\rbody)'], dtype=object))
# ([93, 2], array(['agdid', 'bird'], dtype=object))
# ([94, 2], array(['aġul tiġurdin', 'to reverse'], dtype=object))
# ([95, 2], array(['ahssan', 'barber'], dtype=object))
# ([96, 2], array(['al', 'to cry; to weep'], dtype=object))
# ([97, 2], array(['amarš', 'start of motor (n)'], dtype=object))
# ([98, 2], array(['amwur', 'scythe'], dtype=object))
# ([99, 2], array(['anuguď', 'sheep'], dtype=object))
# ([100, 2], array(['ariaz', 'man'], dtype=object))
# ([101, 2], array(['asggas', 'year'], dtype=object))
# ([102, 2], array(['asnsar', 'necklace'], dtype=object))
# ([103, 2], array(['avray', 'something that hurts\r(on body)'], dtype=object))
# ([104, 2], array(['axdil', 'belly; stomach'], dtype=object))
# ([105, 2], array(['azalim', 'onion'], dtype=object))
# ([106, 2], array(['aعskri', 'military; soldier'], dtype=object))
# ([107, 2], array(['bllati', 'wait (command)'], dtype=object))
# ([108, 2], array(['bxxr', 'to fumigate; to use\rincense to make\rsmoke'],
#       dtype=object))
# ([109, 2], array(['ddifع', 'defense (soccer)'], dtype=object))
# ([110, 2], array(['dġik', 'now'], dtype=object))
# ([111, 2], array(['duhdu', 'to get dizzy'], dtype=object))
# ([112, 2], array(['flan', 'someone'], dtype=object))
# ([113, 2], array(['g ddrع', 'to make something\rhappen, by force'], dtype=object))
# ([114, 2], array(['ġm', 'to dye'], dtype=object))
# ([115, 2], array(['ġušu', 'to cheat'], dtype=object))
# ([116, 2], array(['Hkam', 'to sentence (court)'], dtype=object))
# ([117, 2], array(['Hyyr', 'to be anxious'], dtype=object))
# ([118, 2], array(['ifasn', 'arms; hands'], dtype=object))
# ([119, 2], array(['igllin', 'poor thing'], dtype=object))
# ([120, 2], array(['ikmz', 'finger, thumb'], dtype=object))
# ([121, 2], array(['imriry', 'stack (n)'], dtype=object))
# ([122, 2], array(['iqrruyn', 'horns (animal)'], dtype=object))
# ([123, 2], array(['iskr', 'toenail'], dtype=object))
# ([124, 2], array(['iwatu*', 'self'], dtype=object))
# ([125, 2], array(['izlan', 'songs'], dtype=object))
# ([126, 2], array(['jjuع', 'famine*; greed'], dtype=object))
# ([127, 2], array(['kďu', 'to smell'], dtype=object))
# ([128, 2], array(['krfs', 'to mess up'], dtype=object))
# ([129, 2], array(['lahdaf', 'goals'], dtype=object))
# ([130, 2], array(['lbHar l-abyad l-\rmutawassit', 'Meditteranean Sea'], dtype=object))
# ([131, 2], array(['lfamila', 'relative'], dtype=object))
# ([132, 2], array(['lfurmasyun', 'training'], dtype=object))
# ([133, 2], array(['lhawa', 'air; breeze in house'], dtype=object))
# ([134, 2], array(['lHwayj', 'clothes; things'], dtype=object))
# ([135, 2], array(['ljir', 'plaster'], dtype=object))
# ([136, 2], array(['lkrik', 'jack, tire'], dtype=object))
# ([137, 2], array(['lmal', 'sheep and goats'], dtype=object))
# ([138, 2], array(['lmjarib', 'stairs'], dtype=object))
# ([139, 2], array(['lmswak', 'toothpick'], dtype=object))
# ([140, 2], array(['lmعllm', 'craftsperson'], dtype=object))
# ([141, 2], array(['lqrfa', 'cinnamon'], dtype=object))
# ([142, 2], array(['lward', 'rose (flower)'], dtype=object))
# ([143, 2], array(['lعaşima', 'capital (n)'], dtype=object))
# ([144, 2], array(['mamnuع', 'forbidden'], dtype=object))
# ([145, 2], array(['mġi', 'to sprout'], dtype=object))
# ([146, 2], array(['mnu', 'to look in mirror'], dtype=object))
# ([147, 2], array(['murabbaع', 'square (geometry)'], dtype=object))
# ([148, 2], array(['narzm', 'to be loose'], dtype=object))
# ([149, 2], array(['nkin', 'I'], dtype=object))
# ([150, 2], array(['-nsn', 'their (M)'], dtype=object))
# ([151, 2], array(['qillu', 'corn'], dtype=object))
# ([152, 2], array(['qşşr', 'to flirt'], dtype=object))
# ([153, 2], array(['rjij', 'to convulse; to\rtremble'], dtype=object))
# ([154, 2], array(['rsa', 'to stop doing\rsomething'], dtype=object))
# ([155, 2], array(['saHafi', 'journalist'], dtype=object))
# ([156, 2], array(['sbdd', 'to make stop'], dtype=object))
# ([157, 2], array(['sfliliy', 'to glean; to shine\r(sun)'], dtype=object))
# ([158, 2], array(['šhriya', 'salary'], dtype=object))
# ([159, 2], array(['siuġ', 'to make graze'], dtype=object))
# ([160, 2], array(['slip', 'panties; underwear'], dtype=object))
# ([161, 2], array(['snnd', 'to lie down'], dtype=object))
# ([162, 2], array(['s-sail', 'liquid*'], dtype=object))
# ([163, 2], array(['ssird', 'to bathe; to clean'], dtype=object))
# ([164, 2], array(['ššţ', 'to slip'], dtype=object))
# ([165, 2], array(['sti', 'to choose; to\rseparate; to be\rseparate'], dtype=object))
# ([166, 2], array(['šuwaya', 'brochette racks; grill'], dtype=object))
# ([167, 2], array(['šعl', 'to light*; to turn on'], dtype=object))
# ([168, 2], array(['tafllaHt', 'agriculture'], dtype=object))
# ([169, 2], array(['taguni', 'sleep'], dtype=object))
# ([170, 2], array(['takula', 'mask of pregnancy'], dtype=object))
# ([171, 2], array(['tamgurt', 'scythe'], dtype=object))
# ([172, 2], array(['taqfift', 'basket'], dtype=object))
# ([173, 2], array(['taslmia', 'baby'], dtype=object))
# ([174, 2], array(['tawtult', 'common hare; rabbit'], dtype=object))
# ([175, 2], array(['taعjliyt', 'calf (cow)'], dtype=object))
# ([176, 2], array(['tifinaġ', 'alphabet, Tamazight'], dtype=object))
# ([177, 2], array(['tiHwarin', 'bowls'], dtype=object))
# ([178, 2], array(['tinnġ', 'ours'], dtype=object))
# ([179, 2], array(['tislit n iyjnna', 'rainbow'], dtype=object))
# ([180, 2], array(['tiعzzit', 'bravery'], dtype=object))
# ([181, 2], array(['triţwar', 'curb'], dtype=object))
# ([182, 2], array(['ţţmع', 'greed'], dtype=object))
# ([183, 2], array(['tuxmas', 'teeth'], dtype=object))
# ([184, 2], array(['unfus', 'air; breath (n)'], dtype=object))
# ([185, 2], array(['ut (conj) s rrkl', 'to kick'], dtype=object))
# ([186, 2], array(['watx', 'this'], dtype=object))
# ([187, 2], array(['xllf',
#        'to multiply (be fruitful)\r(agriculture); to\rchange (clothes); to\rshift (car gears)'],
#       dtype=object))
# ([188, 2], array(['yan', '1'], dtype=object))
# ([189, 2], array(['zdr', 'to be deep'], dtype=object))
# ([190, 2], array(['zur', 'to be fat; to be thick;'], dtype=object))
# ([191, 2], array(['zعtut', 'monkey; barbary'], dtype=object))
# ([192, 4], array(['to applaud', 'ut rršš', 'kkat rršš', 'wtġ rršš'], dtype=object))
# ([193, 4], array(['to be a lot', '.عtu', '.عttu', '.عtiġ'], dtype=object))
# ([194, 4], array(['to be calm', 'hddn', 'thddan', 'hddnġ'], dtype=object))
# ([195, 4], array(['to be curvy', 'frġ', 'frrġ', 'frrq'], dtype=object))
# ([196, 4], array(['to be fast', 'srbi', 'tsrbay', 'srbiġ'], dtype=object))
# ([197, 4], array(['to be hot', 'Hmu', 'tHmu', 'Hmiġ'], dtype=object))
# ([198, 4], array(['to be lost in thought', 'xmm', 'txmmam', "xmm'mġ"], dtype=object))
# ([199, 4], array(['to be poor', 'dعf', 'tďعaf', 'ďعfġ'], dtype=object))
# ([200, 4], array(['to be sifted', 'afuf', 'tifif', 'afufġ'], dtype=object))
# ([201, 4], array(['to be upset', 'qllq', 'tqllaq', 'qllqġ'], dtype=object))
# ([202, 4], array(['to benefit from', 'snfع', 'snfaع', 'snfعġ'], dtype=object))
# ([203, 4], array(['to breathe', 'sunfs', 'sunfus', 'sunfsġ'], dtype=object))
# ([204, 4], array(['to change (money)', 'şrrf', 'tşrraf', 'şrrfġ'], dtype=object))
# ([205, 4], array(['to confuse', 'xrbq', 'txrbaq', 'xrbqġ'], dtype=object))
# ([206, 4], array(['to cut (grass)', 'Hšš', 'tHšaš', 'Hššiġ'], dtype=object))
# ([207, 4], array(['to disappear', 'ašk', 'taška', 'uškiġ'], dtype=object))
# ([208, 4], array(['to dress', 'ls', 'lssa', 'lsiġ'], dtype=object))
# ([209, 4], array(['to enroll', 'qyyd', 'tqyyad', 'qyydġ'], dtype=object))
# ([210, 4], array(['to fake', 'zwwr', 'tzwwar', 'zwwrġ'], dtype=object))
# ([211, 4], array(['to fit', 'ga', 'tgga', 'giġ'], dtype=object))
# ([212, 4], array(['to gain', 'rbH', 'trbaH', 'rbHġ'], dtype=object))
# ([213, 4], array(['to give permission', 'k ladn', 'akka ladn', 'kiġ ladn'],
#       dtype=object))
# ([214, 4], array(['to guard', 'Hďu', 'Hţţu', 'Hďiġ'], dtype=object))
# ([215, 4], array(['to have sex (euphemism)', 'jamع', 'tjamaع', 'jamعġ'], dtype=object))
# ([216, 4], array(['to husk', 'zlm', 'zllm', 'zlmġ'], dtype=object))
# ([217, 4], array(['to kick', 'ut (conj) s rrkl', 'kat s rrkl', 'utġ s rrkl'],
#       dtype=object))
# ([218, 4], array(['to let go (of something)', 'zdu', 'zddu', 'zdiġ'], dtype=object))
# ([219, 4], array(['to long for', 'tnġa* taġufi n', 'nqqa* tġufi n', 'tnġayi tġufi'],
#       dtype=object))
# ([220, 4], array(['to make', 'Hiyya', 'tHiyya', 'Hiyyaġ'], dtype=object))
# ([221, 4], array(['to make noise', 'sďďع', 'tsďďaع', 'sďďع'], dtype=object))
# ([222, 4], array(['to mediate', 'şalH', 'tşalaH', 'şalHġ'], dtype=object))
# ([223, 4], array(['to need', 'xssa (reflexive)', 'ttxşşa', 'ixşşay-i'], dtype=object))
# ([224, 4], array(['to pay attention', 'rar lbal', 'trara lbal', 'ruriġ lbal'],
#       dtype=object))
# ([225, 4], array(['to prevent', 'mnع', 'tmnaع', 'mnعġ'], dtype=object))
# ([226, 4], array(['to rape', 'ġtaşb', 'tġtaşab', 'ġtaşbġ'], dtype=object))
# ([227, 4], array(['to resemble', 'aġ', 'taġ', "aġ'ġ"], dtype=object))
# ([228, 4], array(['to say', 'ini', 'tini', 'nniġ'], dtype=object))
# ([229, 4], array(['to shake hands with/greet\reach other', 'msllam', 'tmsllam',
#        'msllamġ'], dtype=object))
# ([230, 4], array(['to skin', 'uzu', 'tuzu', 'azuġ'], dtype=object))
# ([231, 4], array(['to spin', "ml'lly", "tml'llay", "ml'llyġ"], dtype=object))
# ([232, 4], array(['to step on', 'akl xf', 'takl xf', 'uklġ xf'], dtype=object))
# ([233, 4], array(['to swallow', 'lqm', 'lqqm', 'lqmġ'], dtype=object))
# ([234, 4], array(['to teach', '.عllm', 'tعllam', '.عllmġ'], dtype=object))
# ([235, 4], array(['to tie (i.e. cow)', 'krf', 'krrf', 'krfġ'], dtype=object))
# ([236, 4], array(['to type', 'ara', 'tara', 'araġ'], dtype=object))
# ([237, 4], array(['to wake up (open eyes)', 'fafa', 'tfafa', 'fafaġ'], dtype=object))
# ([238, 4], array(['to wink', 'ġmz', 'tġmaz', 'ġmzġ'], dtype=object))
# ([239, 4], array(['to yell', 'sġuy', 'sġuyyu', 'sġuyġ'], dtype=object))
# ([240, 2], array(['Chad', 'tšad'], dtype=object))
# ([241, 2], array(['Honduras', 'alhinduras'], dtype=object))
# ([242, 2], array(['Mongolia', 'manġuliya'], dtype=object))
# ([243, 2], array(['Tunisia', 'tuns'], dtype=object))
# ([244, 2], array(['Zimbabwe', 'zimbabway'], dtype=object))
# ([245, 3], array(['rrbi lman', 'May God send peace',
#        'said to someone who is traveling; when talking\rabout something that is supposed to happen in\rthe future'],
#       dtype=object))
# ([246, 3], array(['mš iktab (rrbi)', 'if it is written',
#        'used to talk about future plans'], dtype=object))

# %%
# Create mapping from new table indices to sections
def get_section_for_original_index(orig_idx):
    """Get section name for original table index"""
    for section_name, info in sections.items():
        if info['start'] <= orig_idx <= info['end']:
            return section_name
    return None

# Build new section mappings
new_sections = {name: [] for name in sections.keys()}
table_to_section = {}

current_new_idx = 0
for orig_idx in range(len(split_mapping)):
    section_name = get_section_for_original_index(orig_idx)
    if section_name:
        # Get the new indices for this original table
        new_indices = split_mapping[orig_idx]
        for new_idx in new_indices:
            if new_idx < len(all_tables):
                new_sections[section_name].append(all_tables[new_idx])
                table_to_section[new_idx] = section_name

print("Tables per section after splitting:")
for section_name, tables in new_sections.items():
    print(f"{section_name}: {len(tables)} tables")
    
    # Show sample from first table in each section
    if tables and len(tables[0]) > 0:
        print(f"  Sample from first table: {tables[0].shape}")
        print(f"  Columns: {list(tables[0].columns)}")
        if len(tables[0]) > 0:
            print(f"  First row: {tables[0].iloc[0].tolist()}")
            print(f"  Last row: {tables[0].iloc[-1].tolist()} ")
        
        print(f"  Sample from last table: {tables[-1].shape}")
        print(f"  Columns: {list(tables[-1].columns)}")
        if len(tables[-1]) > 0:
            print(f"  First row: {tables[-1].iloc[0].tolist()}")
            print(f"  Last row: {tables[-1].iloc[-1].tolist()} ")
# Out:
# Tables per section after splitting:
# english_tamazight: 90 tables
#   Sample from first table: (38, 2)
#   Columns: ['1', 'yan; yiwn/yat, yiwt']
#   First row: ['2', 'sin/snat']
#   Last row: ['a lot (number)', '.عtan; gudin']
#   Sample from last table: (22, 2)
#   Columns: ['you (F, pl) (indirect', '-awnt']
#   First row: ['you (M)', 'ky']
#   Last row: ['zoo', 'lHadiqa n lHayawan']
# tamazight_english: 102 tables
#   Sample from first table: (35, 2)
#   Columns: ['.عada', 'to infect']
#   First row: ['.عadi', 'normal']
#   Last row: ['.عniġ', 'I think so; maybe;\rperhaps; probably']
#   Sample from last table: (33, 2)
#   Columns: ['zwar', 'first (adv)']
#   First row: ['zwu', 'to dry']
#   Last row: ['zعtut', 'monkey; barbary']
# verbs: 48 tables
#   Sample from first table: (27, 4)
#   Columns: ['English', 'Infinitive', 'Present continuous', '1st person past']
#   First row: ['to absorb', 'su', 'ssa', 'swiġ']
#   Last row: ['to applaud', 'ut rršš', 'kkat rršš', 'wtġ rršš']
#   Sample from last table: (22, 4)
#   Columns: ['to wink', 'qqn (conj) tiţ', 'tqqn tiţ', 'qqnġ tiţ']
#   First row: ['to wipe', 'sfď', 'sffď', 'sfďġ']
#   Last row: ['to yell', 'sġuy', 'sġuyyu', 'sġuyġ']
# countries: 5 tables
#   Sample from first table: (36, 2)
#   Columns: ['Abkhazia', 'abxazia']
#   First row: ['Afghanistan', 'afġanistan']
#   Last row: ['Chad', 'tšad']
#   Sample from last table: (8, 2)
#   Columns: ['Uruguay', "l'urugway"]
#   First row: ['Uzbekistan', 'uzbakistan']
#   Last row: ['Zimbabwe', 'zimbabway']
# god_phrases: 2 tables
#   Sample from first table: (19, 3)
#   Columns: ['Phrase', 'English translation', 'When used']
#   First row: ['bismillah', 'in the name of God', 'before eating; before doing almost anything']
#   Last row: ['rrbi lman', 'May God send peace', 'said to someone who is traveling; when talking\rabout something that is supposed to happen in\rthe future']
#   Sample from last table: (11, 3)
#   Columns: ['llah irHam lwaldin', 'God bless your parents', 'used to thank someone for something big']
#   First row: ['llah inعl lwaldik', 'God curse your parents', 'big insult; used if someone does something\rreally bad to you (will result a strong negative\rreaction)']
#   Last row: ['mš iktab (rrbi)', 'if it is written', 'used to talk about future plans']

# %%
# Fix column names by converting them to data rows where needed
def fix_table_headers(section_tables, section_name, section_info):
    """Convert misinterpreted column names back to data rows"""
    fixed_tables = []
    
    for i, table in enumerate(section_tables):
        if len(table) == 0:
            fixed_tables.append(table)
            continue
            
        # Create a copy to avoid modifying original
        fixed_table = table.copy()
        
        if section_info['has_header'] and i == 0:
            # First table in Verbs/God Phrases: keep original headers
            print(f"  Table {i}: Keeping original headers {list(fixed_table.columns)}")
            
        else:
            # All other tables: column names are actually data
            current_columns = list(fixed_table.columns)
            print(f"  Table {i}: Converting column names to data row: {current_columns}")
            
            # Create new row from column names
            new_row = pd.DataFrame([current_columns], columns=fixed_table.columns)
            
            # Add this row as first row
            fixed_table = pd.concat([new_row, fixed_table], ignore_index=True)
            
            # Set proper column names based on section
            if section_name == 'english_tamazight':
                fixed_table.columns = ['EN_source', 'ZGH_target']
            elif section_name == 'tamazight_english':
                fixed_table.columns = ['ZGH_source', 'EN_target']
            elif section_name == 'countries':
                fixed_table.columns = ['Country_EN', 'Country_ZGH']
            elif section_name == 'verbs':
                # Use headers from first table
                fixed_table.columns = ['English', 'Infinitive', 'Present continuous', '1st person past']
            elif section_name == 'god_phrases':
                # Use headers from first table
                fixed_table.columns = ['Phrase', 'English translation', 'When used']
        
        fixed_tables.append(fixed_table)
    
    return fixed_tables

# Apply header fixes to all sections
print("Fixing column headers across all sections...")
fixed_sections = {}

for section_name, section_tables in new_sections.items():
    print(f"\nFixing {section_name}:")
    section_info = sections[section_name]
    fixed_tables = fix_table_headers(section_tables, section_name, section_info)
    fixed_sections[section_name] = fixed_tables
    
    # Show sample of first fixed table
    if fixed_tables and len(fixed_tables[0]) > 0:
        print(f"  Sample after fixing - Shape: {fixed_tables[0].shape}")
        print(f"  Columns: {list(fixed_tables[0].columns)}")
        print(f"  First row: {fixed_tables[0].iloc[0].tolist()}")
# Out:
# Fixing column headers across all sections...
#
# Fixing english_tamazight:
#   Table 0: Converting column names to data row: ['1', 'yan; yiwn/yat, yiwt']
#   Table 1: Converting column names to data row: ['a person or place\r(indicates movement)', 'Zars']
#   Table 2: Converting column names to data row: ['Allah (figurative\rspeech)', 'bu itran']
#   Table 3: Converting column names to data row: ['artist', 'Lfnnan']
#   Table 4: Converting column names to data row: ['bangs (hair)', 'tawnza']
#   Table 5: Converting column names to data row: ['beets', 'Lbarba']
#   Table 6: Converting column names to data row: ['blond', 'ašhabun; azrwal']
#   Table 7: Converting column names to data row: ['Unnamed: 0', 'dblij**']
#   Table 8: Converting column names to data row: ['bubbles', 'tibiwlin']
#   Table 9: Converting column names to data row: ['calf (female)', 'Tigizt']
#   Table 10: Converting column names to data row: ['ceiling*', 'sqf']
#   Table 11: Converting column names to data row: ['churn, made from\ranimal skin(n)', 'tijwit']
#   Table 12: Converting column names to data row: ['comedian', 'baqšiš']
#   Table 13: Converting column names to data row: ['counter', 'lkuntwar']
#   Table 14: Converting column names to data row: ['curse, magical', 'taymust']
#   Table 15: Converting column names to data row: ['dirt (on ground)', 'akal; ašal']
#   Table 16: Converting column names to data row: ['dream (n)', 'tawargit']
#   Table 17: Converting column names to data row: ['either', 'ima']
#   Table 18: Converting column names to data row: ['eye', 'ţiţ']
#   Table 19: Converting column names to data row: ['fever', 'tamġart; tawla; sxana']
#   Table 20: Converting column names to data row: ['flatterer', 'asHHar']
#   Table 21: Converting column names to data row: ['form (paper)', 'tawirqt']
#   Table 22: Converting column names to data row: ['girls', 'talqumin; tirbatin;\rtiširatin']
#   Table 23: Converting column names to data row: ['gravestone', 'tanmnirt']
#   Table 24: Converting column names to data row: ['hands', 'ifasn']
#   Table 25: Converting column names to data row: ['heroin', 'ihirwin']
#   Table 26: Converting column names to data row: ['houses', 'tadarwin; tidartwin']
#   Table 27: Converting column names to data row: ['instructions*', 'ttعlimat']
#   Table 28: Converting column names to data row: ['job', 'lxdmt']
#   Table 29: Converting column names to data row: ['leather', 'jjld']
#   Table 30: Converting column names to data row: ['locust', 'tamurġi']
#   Table 31: Converting column names to data row: ['mattress', 'lbayas; namusiya']
#   Table 32: Converting column names to data row: ['piece', 'Unnamed: 0']
#   Table 33: Converting column names to data row: ['mortar and pestle', 'tafrdut']
#   Table 34: Converting column names to data row: ['nature', 'ţţabiعa']
#   Table 35: Converting column names to data row: ['not (for nouns or', 'urid']
#   Table 36: Converting column names to data row: ['opening in front of\rshirt (women)', 'awsi']
#   Table 37: Converting column names to data row: ['panties', 'lgrsun; slip']
#   Table 38: Converting column names to data row: ['people', 'mddn']
#   Table 39: Converting column names to data row: ['phone number', 'nmra n tilifun']
#   Table 40: Converting column names to data row: ['plus (math)', 'zaid']
#   Table 41: Converting column names to data row: ['pressure', 'ďďġţ']
#   Table 42: Converting column names to data row: ['quality', 'kaliti']
#   Table 43: Converting column names to data row: ['religion', 'ddin']
#   Table 44: Converting column names to data row: ['rotten (n)', 'axmmuj']
#   Table 45: Converting column names to data row: ['scissors', 'lmqşş; tuzlin']
#   Table 46: Converting column names to data row: ['sheet', 'lizar']
#   Table 47: Converting column names to data row: ['sink', 'lavabu; ššarij n irukutn']
#   Table 48: Converting column names to data row: ['snow', 'adfl; atfl']
#   Table 49: Converting column names to data row: ['spare (n) (i.e. tire)', 'sikur']
#   Table 50: Converting column names to data row: ['steel wool', 'jiks']
#   Table 51: Converting column names to data row: ['suede', 'ddan']
#   Table 52: Converting column names to data row: ['teaching (n)', 'ttعlim']
#   Table 53: Converting column names to data row: ['them (M) (direct obj.\rpronoun)', '-tn']
#   Table 54: Converting column names to data row: ['tibea', 'aġanim n udar']
#   Table 55: Converting column names to data row: ['to applaud', 'ďhr; şffq; ut rršš; wt\rabqqa']
#   Table 56: Converting column names to data row: ['to be brave', '.عzzu; zعm']
#   Table 57: Converting column names to data row: ['to be dirty', 'jlx; wssx']
#   Table 58: Converting column names to data row: ['to be immature', 'fsis; imzi* lعql']
#   Table 59: Converting column names to data row: ['to be patient', 'şbr']
#   Table 60: Converting column names to data row: ['to be strong', 'şHu']
#   Table 61: Converting column names to data row: ['to benefit from', 'snf;ع stafd**']
#   Table 62: Converting column names to data row: ['to catch up to', 'ssikl']
#   Table 63: Converting column names to data row: ['to cough phlegm', 'sxixi']
#   Table 64: Converting column names to data row: ['to disappear (behind\rsomething)', 'ġġli']
#   Table 65: Converting column names to data row: ['to embroider', 'nqš']
#   Table 66: Converting column names to data row: ['to fear', 'ggd']
#   Table 67: Converting column names to data row: ["to get in someone's\rway", 'tعrrď']
#   Table 68: Converting column names to data row: ['to hang', 'agl']
#   Table 69: Converting column names to data row: ['Unnamed: 0', 'v)']
#   Table 70: Converting column names to data row: ['to leave behind', 'zri']
#   Table 71: Converting column names to data row: ['to lull (a baby)', 'srurd']
#   Table 72: Converting column names to data row: ['to make something\rhappen, by force', 'g ddrع']
#   Table 73: Converting column names to data row: ['Unnamed: 0', '(reflexive)']
#   Table 74: Converting column names to data row: ['to pound', 'ddz']
#   Table 75: Converting column names to data row: ['to recover', 'jji']
#   Table 76: Converting column names to data row: ['to rust', 'sdda']
#   Table 77: Converting column names to data row: ['to sift', 'ssif']
#   Table 78: Converting column names to data row: ['to spread', 'fsr']
#   Table 79: Converting column names to data row: ['to swallow', 'lqm; zrع']
#   Table 80: Converting column names to data row: ['to throw out (liquid)', 'nġl']
#   Table 81: Converting column names to data row: ['to use up', 'smur']
#   Table 82: Converting column names to data row: ['to worship', '.عbd']
#   Table 83: Converting column names to data row: ['trash', 'aşlaH; lkurfi; zzbl']
#   Table 84: Converting column names to data row: ['uncle (on fathers\rside)', '.عmmi']
#   Table 85: Converting column names to data row: ['waist', 'lHzam']
#   Table 86: Converting column names to data row: ['welcome back', '.عlslama']
#   Table 87: Converting column names to data row: ['winch', 'lforj']
#   Table 88: Converting column names to data row: ['worthless', 'ur su (conj in past)']
#   Table 89: Converting column names to data row: ['you (F, pl) (indirect', '-awnt']
#   Sample after fixing - Shape: (39, 2)
#   Columns: ['EN_source', 'ZGH_target']
#   First row: ['1', 'yan; yiwn/yat, yiwt']
#
# Fixing tamazight_english:
#   Table 0: Converting column names to data row: ['.عada', 'to infect']
#   Table 1: Converting column names to data row: ['.عqql', 'to remember']
#   Table 2: Converting column names to data row: ['abra', 'button']
#   Table 3: Converting column names to data row: ['adrar', 'mountain']
#   Table 4: Converting column names to data row: ['agg', 'to look out (window)']
#   Table 5: Converting column names to data row: ['aġulid', 'boulder; mountain']
#   Table 6: Converting column names to data row: ['aHtšun', 'vagina']
#   Table 7: Converting column names to data row: ['alabba n lmnšar', 'sawdust']
#   Table 8: Converting column names to data row: ['amazdar', 'person, degraded']
#   Table 9: Converting column names to data row: ['amxmax', 'person, dignified']
#   Table 10: Converting column names to data row: ['anuguţ', 'ram']
#   Table 11: Converting column names to data row: ['arij', 'until']
#   Table 12: Converting column names to data row: ['asgun', 'typhoid fever']
#   Table 13: Converting column names to data row: ['-asnt', 'them (F) (indirect obj.\rpronoun)']
#   Table 14: Converting column names to data row: ['avrruy n uġrum', 'bread, piece']
#   Table 15: Converting column names to data row: ['Unnamed: 0', '(organ)']
#   Table 16: Converting column names to data row: ['azarig', 'mill']
#   Table 17: Converting column names to data row: ['aعşr', 'footprints']
#   Table 18: Converting column names to data row: ['bnadm', 'person; human being']
#   Table 19: Converting column names to data row: ['bzd', 'to urinate']
#   Table 20: Converting column names to data row: ['ddilit', 'vine']
#   Table 21: Converting column names to data row: ['dhar (relexive)', 'to seem']
#   Table 22: Converting column names to data row: ['dujanbir', 'December']
#   Table 23: Converting column names to data row: ['Unnamed: 0', '(unspecified)']
#   Table 24: Converting column names to data row: ['g ism', 'to name']
#   Table 25: Converting column names to data row: ['ġml', 'to mold']
#   Table 26: Converting column names to data row: ['guz', 'to descend']
#   Table 27: Converting column names to data row: ['Hkm', 'to govern']
#   Table 28: Converting column names to data row: ['Hzzm', 'to be generous; to put\ron a belt; to tie; to\rfasten']
#   Table 29: Converting column names to data row: ['ififl', 'pepper, bell']
#   Table 30: Converting column names to data row: ['igm', 'drawing of water']
#   Table 31: Converting column names to data row: ['ikniwn', 'twins']
#   Table 32: Converting column names to data row: ['imšinaġ', 'like that; thats the\rway!']
#   Table 33: Converting column names to data row: ['iqur udis', 'to be constipated']
#   Table 34: Converting column names to data row: ['iskrlkasn', 'lie (n)']
#   Table 35: Converting column names to data row: ['iwda', 'enough']
#   Table 36: Converting column names to data row: ['izlan', 'wedding songs']
#   Table 37: Converting column names to data row: ['jlb', 'to vaccinate']
#   Table 38: Converting column names to data row: ['kfft', 'to masturbate* (both']
#   Table 39: Converting column names to data row: ['krfş', 'to suffer']
#   Table 40: Converting column names to data row: ['lajudan', 'gendarme, head']
#   Table 41: Converting column names to data row: ['lbhaym', 'livestock']
#   Table 42: Converting column names to data row: ['lfanid', 'pill; birth control pills;\rcandy']
#   Table 43: Converting column names to data row: ['lfurnu', 'stove']
#   Table 44: Converting column names to data row: ['lHayat', 'life*']
#   Table 45: Converting column names to data row: ['lHya', 'good behavior']
#   Table 46: Converting column names to data row: ['ljjn', 'devil']
#   Table 47: Converting column names to data row: ['lkrraţa', 'squeegee']
#   Table 48: Converting column names to data row: ['lmalayka', 'angel(s)']
#   Table 49: Converting column names to data row: ['lmjmr', 'brazier']
#   Table 50: Converting column names to data row: ["lm'sxut(a)", 'naughty person']
#   Table 51: Converting column names to data row: ['lmعqul', 'reasonable']
#   Table 52: Converting column names to data row: ['l-qrqara', 'drain (in shower or\rfloor) (n)']
#   Table 53: Converting column names to data row: ['lwiġ', 'to be soft']
#   Table 54: Converting column names to data row: ['lعaşir', 'juice']
#   Table 55: Converting column names to data row: ['mani', 'direction; where\r(interrogative)']
#   Table 56: Converting column names to data row: ['mgr', 'to harvest (grains)']
#   Table 57: Converting column names to data row: ['mnع', 'to forbid; to prevent;\rto prohibit; to stop\rsomeone from doing\rsomething']
#   Table 58: Converting column names to data row: ['muš', 'cat']
#   Table 59: Converting column names to data row: ['nayb', 'representative (in']
#   Table 60: Converting column names to data row: ['-nknt', 'your (F, pl)']
#   Table 61: Converting column names to data row: ['-nsnt', 'their (F)']
#   Table 62: Converting column names to data row: ['qiyd', 'to write down\r(something legal)']
#   Table 63: Converting column names to data row: ['qulb', 'to trick']
#   Table 64: Converting column names to data row: ['rkiz', 'to be cloudy (water);\rto be muddy']
#   Table 65: Converting column names to data row: ['ršaqt', 'fun']
#   Table 66: Converting column names to data row: ['şak', 'purse']
#   Table 67: Converting column names to data row: ['sbďi', 'to make pop']
#   Table 68: Converting column names to data row: ['sfnj', 'doughnut']
#   Table 69: Converting column names to data row: ['sHrm', 'to prevent someone\rfrom doing\rsomething; to prohibit']
#   Table 70: Converting column names to data row: ['siwd', 'to scare']
#   Table 71: Converting column names to data row: ['sll', 'to hear']
#   Table 72: Converting column names to data row: ['snqlb', 'to flip; to turn\rsomething over']
#   Table 73: Converting column names to data row: ['ššamal', 'north']
#   Table 74: Converting column names to data row: ['ssirw', 'to assist somone\rgiving birth; to make a\rwoman pregnant\r(man)']
#   Table 75: Converting column names to data row: ['sstl', 'bucket*']
#   Table 76: Converting column names to data row: ['stin', '60']
#   Table 77: Converting column names to data row: ['şuwr', 'to take pictures']
#   Table 78: Converting column names to data row: ['šعria', 'vermicelli']
#   Table 79: Converting column names to data row: ['tafnna', 'cistern']
#   Table 80: Converting column names to data row: ['taguni n ušn', 'sleep, pretend']
#   Table 81: Converting column names to data row: ['takurt', 'ball; soccer']
#   Table 82: Converting column names to data row: ['tamimt', 'honey']
#   Table 83: Converting column names to data row: ['taqrعiyt', 'bottle']
#   Table 84: Converting column names to data row: ['taslt', 'basket']
#   Table 85: Converting column names to data row: ['tawuri', 'work (n)']
#   Table 86: Converting column names to data row: ['taعriya', 'erosion*']
#   Table 87: Converting column names to data row: ['tifiras n uqmu', 'expression (facial)']
#   Table 88: Converting column names to data row: ['tijni', 'sewing (n)']
#   Table 89: Converting column names to data row: ['tinnk', 'yours (M)']
#   Table 90: Converting column names to data row: ['tislit n unzar', 'rainbow']
#   Table 91: Converting column names to data row: ['tjriba', 'experience (n)']
#   Table 92: Converting column names to data row: ['trjm', 'to translate']
#   Table 93: Converting column names to data row: ['ttr', 'to apply for; to ask (in\rmarriage); to beg; to\rlook for (something,\rsomeone); to request;\rto seek']
#   Table 94: Converting column names to data row: ['tuxsin', 'teeth']
#   Table 95: Converting column names to data row: ['ungal', 'black (adj)']
#   Table 96: Converting column names to data row: ['ut (conj) tiġuzvav', 'to squat']
#   Table 97: Converting column names to data row: ['wayd', 'another']
#   Table 98: Converting column names to data row: ['xllş', 'to pay']
#   Table 99: Converting column names to data row: ['yanayr', 'January']
#   Table 100: Converting column names to data row: ['zdu', 'to divorce; to free; to']
#   Table 101: Converting column names to data row: ['zwar', 'first (adv)']
#   Sample after fixing - Shape: (36, 2)
#   Columns: ['ZGH_source', 'EN_target']
#   First row: ['.عada', 'to infect']
#
# Fixing verbs:
#   Table 0: Keeping original headers ['English', 'Infinitive', 'Present continuous', '1st person past']
#   Table 1: Converting column names to data row: ['to applaud', 'wt abqqa', 'kkat abqqa', 'wtġ abqqa']
#   Table 2: Converting column names to data row: ['to be able', 'iġiy', 'tiġiy', 'ġiyġ']
#   Table 3: Converting column names to data row: ['to be careful', 'Hďu (ixf*)', 'Hţţu (ixf*)', 'Hďiġ ixfinu']
#   Table 4: Converting column names to data row: ['to be dangerous', 'g (conj) l-xatar', 'tgga l-xatar', 'giġ l-xatar']
#   Table 5: Converting column names to data row: ['to be fast', 'zrb', 'tzrab', 'zrbġ']
#   Table 6: Converting column names to data row: ['to be hot', 'rġ', 'rqqa', 'rġiġ']
#   Table 7: Converting column names to data row: ['to be loud', 'suqr', 'suqqur', 'suqrġ']
#   Table 8: Converting column names to data row: ['to be poor', 'g (conj) lmskin/igllin', '----', 'giġ lmskin']
#   Table 9: Converting column names to data row: ['to be silent', 'fst', 'tfssta', 'fsstiġ']
#   Table 10: Converting column names to data row: ['to be used to', 'walf', 'twalaf', 'walfġ']
#   Table 11: Converting column names to data row: ['to benefit from*', 'stafd', 'tstafad', 'stafdġ']
#   Table 12: Converting column names to data row: ['to bribe', 'fk (conj) r-ršwa', 'akka r-ršwa', 'fkiġ r-ršwa']
#   Table 13: Converting column names to data row: ['to charge', 'šarji', 'tšarji', 'šarjiġ']
#   Table 14: Converting column names to data row: ['to consume', 'sthlk', 'sthlak', 'sthlkġ']
#   Table 15: Converting column names to data row: ['to cut (hair)', 'Hssn', 'tHssan', 'Hssnġ']
#   Table 16: Converting column names to data row: ['to disappear', 'ġbr', 'tġbar', 'ġbrġ']
#   Table 17: Converting column names to data row: ['to drink', 'su', 'ssa', 'swiġ']
#   Table 18: Converting column names to data row: ['to enroll', 'sjjl', 'tsjjal', 'sjjlġ']
#   Table 19: Converting column names to data row: ['to fall', 'ďr', 'ďďar', 'ďrġ']
#   Table 20: Converting column names to data row: ['to fit', 'yusa(d)', 'tasa(d)', 'usiġ(d)']
#   Table 21: Converting column names to data row: ['to gamble', 'qmmr', 'tqmmar', 'qmmrġ']
#   Table 22: Converting column names to data row: ['to gleam', 'ssid', 'ssidi', 'ssudiġ']
#   Table 23: Converting column names to data row: ['to guard', 'mmatr', 'tmatar', 'mmutrġ']
#   Table 24: Converting column names to data row: ['to have sex (homosexual)', 'myuqu', 'tmyuqqu', 'myuqquġ']
#   Table 25: Converting column names to data row: ['to ignore', 'nxxl', 'tnxxal', 'nxxlġ']
#   Table 26: Converting column names to data row: ['to kiss', 'ssudm', 'ssudum', 'ssudmġ']
#   Table 27: Converting column names to data row: ['to let go of', 'rzm i', 'rzzm i', 'rzmġ i']
#   Table 28: Converting column names to data row: ['to look', 'raعa', 'traعa', 'raعaġ']
#   Table 29: Converting column names to data row: ['to make a woman pregnant\r(man)', 'ssirw', 'ssiriw', 'ssuruġ']
#   Table 30: Converting column names to data row: ['to make noise (like fingernails\ron a chalkboard)', 'grurs', 'tgrurus', 'grursġ']
#   Table 31: Converting column names to data row: ['to meet', 'jmع d', 'tjmaع d', 'jmعġ d']
#   Table 32: Converting column names to data row: ['to obey', 'ţaع', 'tţaع', 'ţaعġ']
#   Table 33: Converting column names to data row: ['to peel', 'qššr', 'tqššar', 'qššrġ']
#   Table 34: Converting column names to data row: ['to prevent someone from\rdoing something', 'sHrm', 'sHram', 'sHrmġ']
#   Table 35: Converting column names to data row: ['to reach', 'awď', 'tawď', 'iwďġ']
#   Table 36: Converting column names to data row: ['to resemble', 'iksil', 'tiksil', 'aksulġ']
#   Table 37: Converting column names to data row: ['to scare', 'siwd', 'ssiwid', 'siwdġ']
#   Table 38: Converting column names to data row: ['to share', 'ssur', 'tsur', 'sarġ']
#   Table 39: Converting column names to data row: ['to skin (i.e. knee, on person )', 'ššnšf', 'ššnšaf', 'ššnšfġ']
#   Table 40: Converting column names to data row: ['to spin wool', 'llm', 'tllm', 'llmġ']
#   Table 41: Converting column names to data row: ['to step over', 'sġl', 'sġal', 'sġlġ']
#   Table 42: Converting column names to data row: ['to swallow', 'zrع', 'zrrع', 'zrعġ']
#   Table 43: Converting column names to data row: ['to teach', 'sġr', 'sġra', 'sġriġ']
#   Table 44: Converting column names to data row: ['to tie closed', 'jnnţ', 'tjnnaţ', 'jnnţġ']
#   Table 45: Converting column names to data row: ['to understand', 'fhm', 'tfham', 'fhmġ']
#   Table 46: Converting column names to data row: ['to walk', 'nzuġ', 'nzzġ', "nzġ'ġ"]
#   Table 47: Converting column names to data row: ['to wink', 'qqn (conj) tiţ', 'tqqn tiţ', 'qqnġ tiţ']
#   Sample after fixing - Shape: (27, 4)
#   Columns: ['English', 'Infinitive', 'Present continuous', '1st person past']
#   First row: ['to absorb', 'su', 'ssa', 'swiġ']
#
# Fixing countries:
#   Table 0: Converting column names to data row: ['Abkhazia', 'abxazia']
#   Table 1: Converting column names to data row: ['Chile', 'ššili']
#   Table 2: Converting column names to data row: ['Hong Kong', 'hung kung']
#   Table 3: Converting column names to data row: ['Solomon Islands', 'juzur ssulumun']
#   Table 4: Converting column names to data row: ['Uruguay', "l'urugway"]
#   Sample after fixing - Shape: (37, 2)
#   Columns: ['Country_EN', 'Country_ZGH']
#   First row: ['Abkhazia', 'abxazia']
#
# Fixing god_phrases:
#   Table 0: Keeping original headers ['Phrase', 'English translation', 'When used']
#   Table 1: Converting column names to data row: ['llah irHam lwaldin', 'God bless your parents', 'used to thank someone for something big']
#   Sample after fixing - Shape: (19, 3)
#   Columns: ['Phrase', 'English translation', 'When used']
#   First row: ['bismillah', 'in the name of God', 'before eating; before doing almost anything']

# %%
# Combine the fixed tables within each section
final_sections = {}

for section_name, section_tables in fixed_sections.items():
    if not section_tables:
        final_sections[section_name] = pd.DataFrame()
        continue
    
    print(f"\nCombining {section_name}...")
    
    # Filter out empty tables
    non_empty_tables = [t for t in section_tables if len(t) > 0]
    
    if not non_empty_tables:
        final_sections[section_name] = pd.DataFrame()
        continue
    
    # Simply concatenate all tables (headers are now properly handled)
    combined_df = pd.concat(non_empty_tables, ignore_index=True)
    
    # Final cleanup - remove any remaining NaN rows
    combined_df = combined_df.dropna()
    
    final_sections[section_name] = combined_df
    print(f"  Final shape: {combined_df.shape}")
    print(f"  Columns: {list(combined_df.columns)}")
    
    # Show sample
    if len(combined_df) > 0:
        print(f"  Sample entries:")
        for i in range(min(3, len(combined_df))):
            print(f"    {combined_df.iloc[i].tolist()}")
        
        # Show last few entries to verify data integrity
        print(f"  Last entries:")
        for i in range(max(0, len(combined_df)-2), len(combined_df)):
            print(f"    {combined_df.iloc[i].tolist()}")
# Out:
# Combining english_tamazight...
#   Final shape: (3548, 2)
#   Columns: ['EN_source', 'ZGH_target']
#   Sample entries:
#     ['1', 'yan; yiwn/yat, yiwt']
#     ['2', 'sin/snat']
#     ['3', 'krad/kradt']
#   Last entries:
#     ['zipper', 'ssnslt']
#     ['zoo', 'lHadiqa n lHayawan']
#
# Combining tamazight_english...
#   Final shape: (3959, 2)
#   Columns: ['ZGH_source', 'EN_target']
#   Sample entries:
#     ['.عada', 'to infect']
#     ['.عadi', 'normal']
#     ['.عanwa', 'wrong (not true)']
#   Last entries:
#     ['zعm ġif', 'to be comfortable']
#     ['zعtut', 'monkey; barbary']
#
# Combining verbs...
#   Final shape: (1384, 4)
#   Columns: ['English', 'Infinitive', 'Present continuous', '1st person past']
#   Sample entries:
#     ['to absorb', 'su', 'ssa', 'swiġ']
#     ['to accept', 'qbl', 'tqbal', 'qblġ']
#     ['to accept', 'qvl', 'tqval', 'qvlġ']
#   Last entries:
#     ['to yawn', 'fa', 'tfa', 'faġ']
#     ['to yell', 'sġuy', 'sġuyyu', 'sġuyġ']
#
# Combining countries...
#   Final shape: (151, 2)
#   Columns: ['Country_EN', 'Country_ZGH']
#   Sample entries:
#     ['Abkhazia', 'abxazia']
#     ['Afghanistan', 'afġanistan']
#     ['Albania', 'albania']
#   Last entries:
#     ['Zambia', 'zambia']
#     ['Zimbabwe', 'zimbabway']
#
# Combining god_phrases...
#   Final shape: (31, 3)
#   Columns: ['Phrase', 'English translation', 'When used']
#   Sample entries:
#     ['bismillah', 'in the name of God', 'before eating; before doing almost anything']
#     ['llahiعawn', 'God help you', 'hello; good bye; literally "may God help you"']
#     ['llah isllim', 'God help you too', 'response to llahiعawn']
#   Last entries:
#     ['ad isxr rrbi', 'May God bless', 'said to crops, children (i.e. when someone\rintroduces his kids, fields or animals to you) (is\rsupposed to keep the evil eye away)']
#     ['mš iktab (rrbi)', 'if it is written', 'used to talk about future plans']

# %%
def clean_for_hf_export(df):
    """Clean DataFrame to ensure HF datasets compatibility"""
    cleaned_df = df.copy()
    
    # Replace problematic characters within text
    for col in cleaned_df.columns:
        if cleaned_df[col].dtype == 'object':  # String columns
            cleaned_df[col] = cleaned_df[col].astype(str).str.replace('\t', ' ', regex=False)
            cleaned_df[col] = cleaned_df[col].str.replace('\n', ' ', regex=False)
            cleaned_df[col] = cleaned_df[col].str.replace('\r', ' ', regex=False)
            # Remove extra whitespace
            cleaned_df[col] = cleaned_df[col].str.strip()
    
    # Remove rows where any cell is empty or just whitespace
    mask = True
    for col in cleaned_df.columns:
        mask = mask & (cleaned_df[col].str.strip() != '') & (cleaned_df[col] != 'nan')
    
    cleaned_df = cleaned_df[mask]
    return cleaned_df

def save_hf_compatible_tsv(df, filepath):
    """Save DataFrame as HF-compatible TSV with proper cleaning"""
    # Clean the data first
    cleaned_df = clean_for_hf_export(df)
    
    # Save with proper TSV formatting
    cleaned_df.to_csv(filepath, sep='\t', index=False, encoding='utf-8', 
                     lineterminator='\n', quoting=1)  # quoting=1 ensures proper escaping
    
    return len(cleaned_df)

# Save each section as HF-compatible TSV
output_dir = Path("data")
output_dir.mkdir(exist_ok=True)

saved_files = []

for section_name, df in final_sections.items():
    if len(df) == 0:
        print(f"\nSkipping empty section: {section_name}")
        continue
    
    filename = output_dir / f"{section_name}.tsv"
    
    # Save with HF-compatible cleaning
    final_rows = save_hf_compatible_tsv(df, filename)
    saved_files.append(filename)
    
    print(f"\nSaved {section_name}: {len(df)} -> {final_rows} rows -> {filename}")

print(f"\nFINAL SUMMARY:")
print(f"- Split 9 concatenated tables into 18 separate tables")
print(f"- Total tables processed: 247")
print(f"- All NaN/null rows removed")
print(f"- Applied HF datasets compatibility cleaning")
print(f"- Saved {len(saved_files)} TSV files in 'data/'")
# Out:
# Saved english_tamazight: 3548 -> 3548 rows -> data\english_tamazight.tsv
#
# Saved tamazight_english: 3959 -> 3959 rows -> data\tamazight_english.tsv
#
# Saved verbs: 1384 -> 1384 rows -> data\verbs.tsv
#
# Saved countries: 151 -> 151 rows -> data\countries.tsv
#
# Saved god_phrases: 31 -> 31 rows -> data\god_phrases.tsv
#
# FINAL SUMMARY:
# - Split 9 concatenated tables into 18 separate tables
# - Total tables processed: 247
# - All NaN/null rows removed
# - Applied HF datasets compatibility cleaning
# - Saved 5 TSV files in 'data/'
